# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import stopwords
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import eli5
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read data

# %%
data = pd.read_csv('D:/tele2_data_hack/email_reports.csv')
data = data.sort_values(by='To.queue.time').reset_index(drop=True)
print(data.shape)
# Out:
# (125938, 10)

# %%
data.head()
# Out:
#      SENDER_ID    SENDER_EMAIL OPERATOR_ID                   ACCEPTOR  \
# 0   token_7747  xxxx@yandex.ru    token_48        spb.vopros@tele2.ru
# 1  token_14226    xxxx@mail.ru    token_50    Saransk.Vopros@tele2.ru
# 2  token_23942    xxxx@mail.ru     token_3     rostov.vopros@tele2.ru
# 3  token_18368    xxxx@mail.ru    token_53  krasnodar.vopros@tele2.ru
# 4  token_21039    xxxx@mail.ru    token_34   kostroma.vopros@tele2.ru
#
#                  SUBJECT        To.queue.time   agent.receive.time  \
# 0         Обратная связь  2088-06-17 02:31:32  2088-06-18 19:48:26
# 1  Re[2]: Обратная связь  2088-06-17 02:31:52  2088-06-18 18:43:45
# 2         Обратная связь  2088-06-17 02:33:14  2088-06-18 18:43:45
# 3         Обратная связь  2088-06-17 02:33:36  2088-06-18 19:49:10
# 4         Обратная связь  2088-06-17 02:33:56  2088-06-18 19:49:17
#
#     treatment.end.time                                            CONTENT  \
# 0  2088-06-18 20:24:59  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 1  2088-06-18 18:58:43    \r\nвся необходимая информация отображена в ...
# 2  2088-06-18 18:47:06  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 3  2088-06-18 19:53:57  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 4  2088-06-18 19:59:48  Тело письма\r\n\r\nОтметьте, в каком регионе В...
#
#                                           ANSWERTEXT
# 0  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx!\r\n\r...
# 1  Здравствуйте, xxxxx xxxxx xxxxx!\r\nБлагодарим...
# 2  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx!\r\nБл...
# 3  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx! ¦\r\n...
# 4  \r\n\r\nАлександр, доброго времени суток! ;)\r...

# %% [markdown]
# # determine fraction of each problem

# %%
# for training classifier use only letters for support 
print(data.shape)
data = data[data['CONTENT'].apply(lambda x: 'Тело письма' in str(x))].reset_index(drop=True)
print(data.shape)
# Out:
# (125938, 10)
# (102898, 10)

# %% [markdown]
# ### Get question from user and topic of this question

# %%
def get_topic(x):
    """""
    Get topic from letter's body  
    """""
    ret = ''
    try:
        ret = x.split('Выберите тему обращения: ')[1].split('\r')[0]
    except:
        pass
    return ret

def get_question(x):
    """""
    Get question from letter's body
    """""
    ret = ''
    try:
        ret = x.split('Выберите тему обращения: ')[1].split('\r')[1].split('\nЗадайте ваш вопрос или опишите проблему: ')[1]
    except:
        pass
    return ret


data['topic'] = data['CONTENT'].apply(lambda x: get_topic(x))
data['question'] = data['CONTENT'].apply(lambda x: get_question(x))

# %% [markdown]
# ### Statistics of topics

# %%
# calculate statisitics of topic 
temp = data[['topic','CONTENT']].groupby('topic').agg('count').reset_index()
temp = temp.rename_axis({'CONTENT':'Number of questions'},axis=1)
num_q = np.sum(temp['Number of questions'])
temp = temp[temp['Number of questions']>1200].reset_index(drop=True)

temp['Topic fraction'] = temp['Number of questions'] / num_q * 100
print('Most popular topics fraction: ', np.sum(temp['Topic fraction']), '%')
# Out:
# Most popular topics fraction:  97.50335283484615 %

# %%
temp.sort_values(by='Topic fraction', ascending=False)
# Out:
#                                   topic  Number of questions  Topic fraction
# 8                                прочее                24434       23.745845
# 10                        тарифыИУслуги                18770       18.241365
# 3                     мобильныйИнтернет                15918       15.469688
# 6                    подключенныеУслуги                 9112        8.855371
# 2                         личныйКабинет                 7379        7.171179
# 9              роумингИЗонаОбслуживания                 6732        6.542401
# 7   поступлениеПлатежейОшибочныеПлатежи                 6045        5.874750
# 1            детализацияСчётаИлиЗвонков                 5474        5.319831
# 0      блокировкаИРазблокировкаSimКарты                 2412        2.344069
# 5                     подключениеКTele2                 2398        2.330463
# 4                   переносНомераВTele2                 1655        1.608389

# %%
most_freq_topics = list(temp['topic'])

# %%
# keep only freq topics 
data = data[data['topic'].apply(lambda x: x in most_freq_topics)].reset_index(drop=True)

# %% [markdown]
# ### Prepare data for test classification

# %%
# split texts in train and test part, time-series split, i.e. shuffle=False (data was sorted by time before) 
X_train, X_test, y_train, y_test = train_test_split(data['question'], data['topic'], 
                                                    shuffle=False, 
                                                    test_size=0.1)

# %%
# transfrom 'string' labels in 'int' labels 
le = LabelEncoder()
y_train_labels = le.fit_transform(y_train)
y_test_labels = le.transform(y_test)

# %%
# del all 'xx', 'xxx', 'xxxx' - i.e. artefacts of tele2 data protection
xs_seq = []
for n_x in np.arange(10,2,-1):
    xs_seq.append('x'*n_x)
    
def preprocess_string(x):
    for xs in xs_seq:
        x = re.sub(xs, ' ', x)
    return x

X_train = X_train.apply(lambda x: preprocess_string(x))
X_test = X_test.apply(lambda x: preprocess_string(x))

# %%
# download stopwords from NLTK 
stopWords = set(stopwords.words('russian'))
stopWords = list(stopWords)
stopWords = stopWords + ['вечер', 'добрый', 'день', 'скажите', 'пожалуйста', 'спасибо', 'ли', 'почему', 'вопрос']
stopWords.remove('не')
stopWords = set(stopWords)
print('Number of stop words:', len(stopWords))
# Out:
# Number of stop words: 158

# %%
# fit TFIDF
tfidf = TfidfVectorizer(ngram_range=(1, 2), min_df=100, max_df=0.99, stop_words=stopWords)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
tfidf.vocabulary_
# Out:
# {'пока не': 1556,
#  'подписку tuboteka': 1537,
#  'офисе': 1343,
#  'дело': 443,
#  'кому': 766,
#  'давно': 400,
#  'поселке': 1640,
#  'ул': 2302,
#  'вообще не': 316,
#  'писала': 1432,
#  'прошу вернуть': 1794,
#  'думал': 532,
#  'вижу': 282,
#  'разы выше': 1842,
#  'живу': 547,
#  'настроить': 987,
#  'интернета': 679,
#  'тт': 2274,
#  'какие условия': 724,
#  'постоянные': 1650,
#  'регул': 1862,
#  'полное': 1564,
#  'поэтому': 1661,
#  'минут гб': 864,
#  'суд': 2166,
#  'которую': 784,
#  'безлимитный': 209,
#  'телефона': 2242,
#  'приложение теле2': 1696,
#  'произошло списание': 1760,
#  'раньше': 1848,
#  'вернуть денежные': 262,
#  'оказывается': 1227,
#  'звонить': 602,
#  'услугу которую': 2334,
#  'получить пароль': 1584,
#  'здравствуйте хочу': 636,
#  'сегодня': 1951,
#  'стороны': 2163,
#  'перезагрузка': 1397,
#  'оператора это': 1236,
#  'никакого': 1123,
#  'вашими': 246,
#  'такие': 2192,
#  'деньги счета': 460,
#  'вами': 233,
#  'нахожусь': 995,
#  'не перенесли': 1039,
#  'перевел': 1387,
#  'входа личный': 342,
#  'мтс': 963,
#  'нечаянно': 1111,
#  'согласие обработку': 2078,
#  'паспортные данные': 1384,
#  'работало': 1816,
#  'не помню': 1057,
#  'не смог': 1072,
#  'роутере': 1882,
#  'обратилась': 1199,
#  'последнее время': 1643,
#  'меню': 846,
#  'закончились': 572,
#  'проблемы': 1747,
#  'заявка': 595,
#  'списанные деньги': 2119,
#  'работал': 1815,
#  'переходе': 1418,
#  'писал': 1431,
#  '4g': 101,
#  'могу отправить': 907,
#  'уточните': 2344,
#  'гигабайт': 376,
#  'россии': 1877,
#  'поясните': 1666,
#  'привязать': 1688,
#  'чёрный': 2401,
#  'ул x000d_': 2303,
#  'мин': 861,
#  'wi fi': 153,
#  'зона': 642,
#  'это ограничение': 2421,
#  '00 00': 1,
#  'компания': 765,
#  'позвонила': 1549,
#  'временно': 328,
#  'такую': 2199,
#  'снято': 2067,
#  'июля': 706,
#  'true': 145,
#  'потерял': 1655,
#  'рассмотреть': 1850,
#  'интернета не': 681,
#  'уведомления': 2284,
#  'сказать': 1988,
#  'получила': 1580,
#  'вход': 340,
#  'это несправедливо': 2420,
#  'не подключен': 1048,
#  'людей': 829,
#  'сети': 1954,
#  'далее': 401,
#  'оставить': 1264,
#  'примите': 1706,
#  'совершить': 2076,
#  'иначе': 662,
#  'контента': 772,
#  'договора': 486,
#  '200 минут': 49,
#  'прошла': 1786,
#  'sim карту': 140,
#  'включить': 285,
#  'хотелось узнать': 2371,
#  'сгорели': 1943,
#  'стоить': 2158,
#  'лк': 821,
#  'соответственно': 2089,
#  'текущий': 2231,
#  'вернул': 259,
#  'вне': 290,
#  'здравствуйте нахожусь': 621,
#  'платная услуга': 1457,
#  'других': 522,
#  'видимо': 279,
#  'звонки интернет': 607,
#  'другим': 521,
#  'списание средств': 2114,
#  'всей': 332,
#  'не первый': 1038,
#  'самостоятельно': 1909,
#  'подключены': 1513,
#  'списания': 2116,
#  'города': 390,
#  'бесплатный': 215,
#  'отключите услугу': 1301,
#  'личном кабинете': 815,
#  '199': 45,
#  'контент который': 770,
#  'моего счета': 931,
#  'обновился': 1190,
#  'подписка': 1532,
#  'крыму': 803,
#  'снимаются': 2059,
#  'приобрести': 1712,
#  'интернет': 665,
#  'собой': 2073,
#  'понимание': 1613,
#  'пароль не': 1378,
#  'заблокировать номер': 553,
#  'отключить автоплатеж': 1303,
#  'найти': 975,
#  'взять обещанный': 275,
#  'украли': 2301,
#  'опуститься': 1255,
#  'плохое': 1480,
#  'билайна': 221,
#  'подключить услугу': 1529,
#  'никто не': 1127,
#  'несколько': 1105,
#  'жалобу центральный': 544,
#  'случилось': 2022,
#  'связью': 1942,
#  'разные': 1833,
#  'разговора': 1829,
#  'моем': 936,
#  'факту': 2353,
#  'абонентам': 170,
#  'идёт': 648,
#  'отключить': 1302,
#  '3g': 91,
#  'кабинет не': 712,
#  'мобильной связи': 888,
#  'роутер': 1881,
#  'списываются деньги': 2134,
#  'остаться': 1280,
#  'фото': 2359,
#  'сим картой': 1969,
#  'пакет': 1363,
#  'настройки интернета': 990,
#  'год': 386,
#  'хватало': 2364,
#  'данным': 420,
#  'минус': 862,
#  'хочу перейти': 2377,
#  'вопросу': 319,
#  'проходит': 1784,
#  '3гб': 93,
#  'нужно подключить': 1171,
#  'не хватает': 1077,
#  'никак не': 1118,
#  'звонки теле2': 610,
#  'не правильно': 1062,
#  'мошенничество': 958,
#  'вопросы': 320,
#  'дополнительных': 509,
#  '30 сут': 77,
#  'отношению клиенту': 1316,
#  'подключен': 1500,
#  'ввести': 250,
#  'сим карте': 1968,
#  'смену': 2033,
#  '270': 67,
#  'точнее': 2260,
#  'зарегистрирован': 586,
#  'равно': 1823,
#  'пропадает сеть': 1764,
#  '04': 6,
#  'часа': 2389,
#  'конце': 776,
#  'которая': 778,
#  'деньги списали': 457,
#  'хотела узнать': 2369,
#  'банковскую': 205,
#  'нагрузки': 968,
#  'снялись': 2066,
#  'снимают деньги': 2058,
#  'пользоваться не': 1592,
#  'такого не': 2196,
#  'уровень': 2307,
#  'смотреть': 2038,
#  'номер теле': 1144,
#  'скорости мобильного': 1997,
#  '100р': 22,
#  '30': 72,
#  'недоступна': 1092,
#  'текстом': 2230,
#  'перестал': 1411,
#  'puk код': 137,
#  'причине моих': 1728,
#  'скорее': 1993,
#  'остальные': 1272,
#  '200 рублей': 51,
#  'хочу поменять': 2379,
#  'видно': 281,
#  'тарифов': 2223,
#  'сотовой связи': 2093,
#  'рубля': 1895,
#  'смогла': 2036,
#  '06 18': 9,
#  'модеме': 925,
#  'подписки': 1534,
#  'карты': 743,
#  'регионе': 1860,
#  'заблокировать сим': 554,
#  'жалобу': 543,
#  'карту': 741,
#  'подписке': 1533,
#  'сказал': 1984,
#  'пароль': 1375,
#  'могу обменять': 905,
#  'момент нахожусь': 950,
#  'понятно': 1618,
#  'новую': 1133,
#  'платную подписку': 1460,
#  'отпечатку пальца': 1319,
#  'могу зайти': 902,
#  'не нужно': 1031,
#  'момента': 951,
#  'августа': 185,
#  'оплаты': 1247,
#  'переход': 1415,
#  'сняты': 2068,
#  'свой номер': 1927,
#  'ответ': 1281,
#  'моим': 946,
#  'обмен': 1183,
#  'обслуживание': 1209,
#  'минут смс': 867,
#  '24': 57,
#  'июля года': 707,
#  'смог': 2035,
#  'хочу подключить': 2378,
#  'появился': 1663,
#  'определенного количества': 1254,
#  'уважением': 2282,
#  'соцсети': 2101,
#  'город': 389,
#  'тарифного': 2215,
#  'устранить': 2342,
#  'здравствуйте прошу': 629,
#  'тариф беспредельно': 2201,
#  'эл': 2405,
#  'ответьте': 1285,
#  'ловит интернет': 823,
#  'абонентской': 176,
#  'хочу узнать': 2380,
#  'теле2': 2236,
#  'перенесли': 1401,
#  'сбербанка': 1914,
#  'хотел узнать': 2367,
#  'пакет смс': 1367,
#  'моего номера': 929,
#  'ошибочный': 1359,
#  'пишут': 1440,
#  'логотипы': 828,
#  'tele': 142,
#  'обнаружил': 1188,
#  'получать': 1576,
#  'пришлось': 1738,
#  'не доступен': 1015,
#  'качество': 746,
#  'логин пароль': 827,
#  'мобильный интернет': 892,
#  'mail ru': 133,
#  'следующего': 2010,
#  'сочи': 2102,
#  '350р': 89,
#  'аб': 165,
#  'включается': 284,
#  'входящих': 348,
#  'пользования': 1589,
#  'номер теле2': 1145,
#  'доступна': 516,
#  'го': 381,
#  '30 06': 73,
#  'страницы': 2165,
#  'решите проблему': 1873,
#  'вторую': 339,
#  'гб интернета': 373,
#  'та': 2186,
#  'стало': 2149,
#  'обратно': 1202,
#  'являюсь вашим': 2434,
#  '28': 68,
#  'нам': 976,
#  'теле xx': 2234,
#  'карта': 737,
#  'x000d_': 155,
#  'условиям тарифа': 2316,
#  'перейти тариф': 1400,
#  'оформлена': 1346,
#  'сказано': 1987,
#  'ваша': 235,
#  'обращался': 1204,
#  'сайт': 1898,
#  'могу позвонить': 911,
#  'её не': 542,
#  'другом': 527,
#  'персональных': 1428,
#  'другие': 520,
#  'симка': 1972,
#  'не показывает': 1051,
#  'плачу': 1474,
#  'могла': 896,
#  'предложили': 1676,
#  'качестве': 745,
#  '500 мб': 107,
#  'пользовался': 1587,
#  'прошу дать': 1795,
#  'кабинету': 717,
#  'опцию': 1258,
#  'недель': 1087,
#  'смене тарифа': 2027,
#  '300 рублей': 80,
#  'самом': 1908,
#  'телефонов': 2248,
#  'проверил': 1750,
#  'региона': 1859,
#  'мобильное приложение': 886,
#  'понять': 1619,
#  'везде': 256,
#  'средства': 2139,
#  'лицевого': 810,
#  'платной': 1458,
#  'остаток': 1279,
#  'одного': 1222,
#  'снимали': 2053,
#  'поменять тариф': 1603,
#  'подключается': 1492,
#  'слишком': 2014,
#  'совершать': 2074,
#  'не смогла': 1073,
#  'никому': 1125,
#  'которому': 783,
#  'списке': 2125,
#  'пришло': 1735,
#  'данная': 405,
#  'пополнил': 1624,
#  'совершенно': 2075,
#  'списываются': 2133,
#  'необходимо': 1099,
#  '300 руб': 79,
#  'прошу предоставить': 1800,
#  'платный': 1465,
#  'платежи': 1453,
#  '250': 60,
#  'убрать': 2278,
#  'здравствуйте отключить': 625,
#  'клиентов': 750,
#  'трафик': 2263,
#  'можем': 942,
#  'сильно': 1965,
#  'зарегистрирована': 587,
#  'списывают деньги': 2132,
#  'тарифном плане': 2218,
#  'заканчивается': 570,
#  'федеральный': 2356,
#  'безлимит': 207,
#  '30 рублей': 76,
#  'убрали': 2277,
#  'другого': 524,
#  'заявки': 596,
#  'денег': 444,
#  'отключается': 1289,
#  'обмена': 1185,
#  'кода': 757,
#  'поскольку': 1641,
#  'плата': 1450,
#  'указано': 2300,
#  'смартфоне': 2024,
#  'стоп номер': 2162,
#  'моей': 935,
#  'мои': 944,
#  '02': 4,
#  'заметил': 577,
#  'такое': 2197,
#  'заблокируйте': 555,
#  'смс сообщения': 2048,
#  'спустя': 2136,
#  'разъяснить': 1840,
#  'проблем': 1739,
#  'подключаете': 1491,
#  'моём': 961,
#  'моб': 880,
#  'сохранением': 2096,
#  'добавить': 477,
#  'июне': 708,
#  'москвы': 955,
#  'не номер': 1028,
#  'сделайте': 1944,
#  'пор': 1637,
#  'исчерпания определенного': 702,
#  'разберитесь': 1825,
#  'запрет': 582,
#  'редко': 1864,
#  'услугу': 2332,
#  'средства якобы': 2141,
#  'обновление': 1192,
#  'сим карту': 1970,
#  'входа': 341,
#  'санкт': 1911,
#  'автоплатеж': 187,
#  'которые не': 787,
#  'действия': 434,
#  'помочь': 1609,
#  'поддержки возникла': 1488,
#  'платные услуги': 1464,
#  'данный номер': 419,
#  'версии': 269,
#  'подключиться': 1530,
#  'тратится': 2262,
#  'абонентская плата': 175,
#  '22': 55,
#  'теле не': 2235,
#  'здравствуйте очень': 626,
#  'вызовы': 357,
#  'итоге': 703,
#  'отсутствие': 1338,
#  'недели': 1085,
#  'экстренные': 2403,
#  'балансе': 200,
#  'неиспользованные': 1094,
#  'возможно': 302,
#  'либо': 808,
#  'дня назад': 476,
#  'звонке': 605,
#  'минут гигабайты': 865,
#  'отправьте стоп': 1336,
#  'ооо': 1231,
#  'свой пароль': 1928,
#  'значит': 639,
#  'пополнить счёт': 1634,
#  'общаться': 1211,
#  'не имелось': 1020,
#  'не нужна': 1030,
#  'считаю': 2181,
#  'прошу помочь': 1798,
#  'номера': 1147,
#  'какие платные': 723,
#  'сеть не': 1958,
#  'смогу': 2037,
#  'фз': 2357,
#  'исходящих': 699,
#  'интернетом не': 685,
#  'образом': 1198,
#  'причина': 1726,
#  'полный': 1567,
#  'бывает': 230,
#  'подключают': 1497,
#  'приложением': 1697,
#  'опции': 1257,
#  'пополнил баланс': 1625,
#  'пакета': 1369,
#  'возврата': 301,
#  'основном': 1262,
#  'заказать детализацию': 566,
#  '10 рублей': 17,
#  'хотела': 2368,
#  '10гб': 23,
#  'извините': 649,
#  'модем': 923,
#  'появилась': 1662,
#  'попытке': 1636,
#  'перейду': 1398,
#  'случайно': 2021,
#  'списали': 2107,
#  'возникла': 310,
#  'минут не': 866,
#  'подключенной': 1509,
#  'началось проседание': 1001,
#  'пошло': 1659,
#  'буду': 227,
#  'внёс': 298,
#  'обработку персональных': 1197,
#  'полном': 1565,
#  'число': 2399,
#  'сайты': 1901,
#  'работает мобильный': 1811,
#  'имелось': 657,
#  'сказала': 1985,
#  'не получил': 1053,
#  'гб не': 375,
#  'каждый месяц': 721,
#  'tv': 149,
#  'уважаемый оператор': 2281,
#  'отключить платную': 1306,
#  'находится': 991,
#  'третий': 2273,
#  'подключенные': 1510,
#  'отключите': 1300,
#  'подтверждения': 1545,
#  'уровне покупке': 2310,
#  'подключена услуга': 1505,
#  'здравствуйте тариф': 632,
#  'практически не': 1672,
#  'отключить услугу': 1309,
#  'входящие звонки': 346,
#  'нагрузки сеть': 969,
#  'деньги списались': 458,
#  'денежные средства': 446,
#  'ваш': 234,
#  'приложения теле2': 1704,
#  'подключён': 1531,
#  'обл': 1179,
#  'veseluxa': 150,
#  'вашей': 240,
#  'сколько стоит': 1990,
#  'абонентом': 172,
#  'программы': 1753,
#  'условию договора': 2312,
#  'одна': 1219,
#  'ловит': 822,
#  'кого': 755,
#  'операторов': 1237,
#  'приходят смс': 1723,
#  'баланс положительный': 198,
#  'моем номере': 937,
#  'недавно': 1084,
#  'электронную почту': 2408,
#  'приходить': 1721,
#  'используется': 693,
#  'ваша компания': 236,
#  'ведома': 254,
#  'москве': 953,
#  'поменять пароль': 1602,
#  'московской': 956,
#  'абонентская': 174,
#  'скоростью': 2005,
#  'уезжаю': 2292,
#  'подключили': 1522,
#  'девушка': 430,
#  'своём': 1930,
#  'дней': 471,
#  'пропадают': 1765,
#  'не давала': 1012,
#  'доступ интернет': 513,
#  'дальнейшем': 403,
#  'пакет не': 1366,
#  'думаю': 533,
#  'пакете': 1370,
#  '50 смс': 105,
#  'объясните': 1213,
#  'xx': 158,
#  'трафик не': 2265,
#  'дозвониться': 490,
#  'август': 184,
#  'безобразие': 212,
#  'могу пополнить': 916,
#  'км': 753,
#  'телефоны': 2251,
#  'сняли 30': 2064,
#  'мобильная': 881,
#  'пополнила счёт': 1629,
#  'около': 1228,
#  'гигобайты': 379,
#  'протяжении': 1783,
#  'крым': 802,
#  'минуты гигабайты': 872,
#  'действий': 432,
#  'пароль 30': 1376,
#  'изменили': 651,
#  'положительный': 1573,
#  'значок': 640,
#  'плохо работает': 1479,
#  'поменяла': 1597,
#  'плохой': 1481,
#  'здравствуйте такая': 631,
#  'качество связи': 747,
#  'абонентов': 171,
#  'городской': 392,
#  'подключила услугу': 1520,
#  'этим': 2412,
#  'списать': 2124,
#  'зоны': 644,
#  'изменилось': 652,
#  'моего счёта': 932,
#  'оповещение': 1251,
#  'теле2 пишет': 2238,
#  'средства размере': 2140,
#  'меньше': 845,
#  'противном': 1781,
#  'стали': 2148,
#  'данных': 421,
#  'отправить sms': 1324,
#  'номер не': 1143,
#  '150 руб': 34,
#  'отправить сообщение': 1326,
#  'расходы': 1856,
#  'соединение': 2081,
#  'находиться': 992,
#  'это отключить': 2422,
#  'время': 329,
#  'функция': 2362,
#  'платных подписок': 1468,
#  'приходит смс': 1718,
#  'пополнить баланс': 1632,
#  'мобильной': 887,
#  'использую': 694,
#  'видео': 277,
#  '100': 18,
#  'зоне': 643,
#  'счёта моего': 2184,
#  'рядом': 1897,
#  'краснодарском крае': 799,
#  '250 рублей': 62,
#  'указана': 2298,
#  'составляет': 2091,
#  'счету': 2180,
#  'вашего оператора': 239,
#  'кончился': 777,
#  'puk': 136,
#  'вынуждена': 361,
#  'новом': 1132,
#  'сих': 1982,
#  'никуда': 1128,
#  'количества трафика': 760,
#  'адресу': 190,
#  'плане': 1443,
#  'моём тарифе': 962,
#  'не помогает': 1058,
#  'согласия': 2079,
#  'гб': 372,
#  'личному кабинету': 817,
#  'домашнем регионе': 501,
#  'остались': 1269,
#  'перехода': 1417,
#  'прошу пояснить': 1799,
#  'просил': 1772,
#  'подтверждение': 1544,
#  'нигде не': 1114,
#  'карты нареканий': 744,
#  'собираюсь': 2072,
#  'не поддерживает': 1043,
#  'списались деньги': 2110,
#  '15 гб': 30,
#  'здравствуйте моего': 620,
#  'приложений': 1701,
#  'надеюсь': 970,
#  'сделать не': 1950,
#  'отключен': 1291,
#  'другом регионе': 528,
#  'пришло смс': 1736,
#  'отправить смс': 1325,
#  'моего ведома': 928,
#  'работает не': 1812,
#  'это время': 2417,
#  'каком основании': 733,
#  'связи этим': 1938,
#  'оплатила': 1244,
#  'com': 124,
#  'проверьте': 1752,
#  'интернет вообще': 666,
#  'смс номера': 2045,
#  'данной ситуации': 411,
#  'числа': 2398,
#  'типа': 2257,
#  'обещанный платёж': 1178,
#  'входящие': 345,
#  'интересует': 664,
#  'экране': 2402,
#  'отправляет': 1328,
#  '25': 59,
#  'мной': 877,
#  'взял': 273,
#  'вопроса': 317,
#  'ближайшее': 224,
#  'оповещения': 1252,
#  'неправильно': 1102,
#  'вашем': 242,
#  'прежний': 1683,
#  'нового': 1130,
#  'ближайшее время': 225,
#  'претензию': 1686,
#  'пакет минут': 1365,
#  'отключение': 1293,
#  'сайта': 1899,
#  'услугу гудок': 2333,
#  'снимались средства': 2055,
#  'карте': 739,
#  'трафика': 2266,
#  '100 смс': 21,
#  'своих': 1925,
#  'офиса': 1342,
#  'подключает': 1490,
#  'оказалось': 1226,
#  'никаких услуг': 1122,
#  'переадресацию': 1386,
#  'грузится': 396,
#  'данный': 417,
#  'звонок': 613,
#  'повторно': 1485,
#  'телефон xx': 2240,
#  'момент': 949,
#  'условиям': 2315,
#  'являюсь': 2432,
#  'должна': 494,
#  'настройки': 989,
#  'сим': 1966,
#  'увидела': 2286,
#  'тарифный план': 2222,
#  'получить': 1582,
#  'действие': 431,
#  'также': 2190,
#  'сетью': 1960,
#  '07': 10,
#  'тариф': 2200,
#  'яндекс': 2437,
#  'счёте': 2185,
#  'вернуть': 261,
#  'минуты гб': 871,
#  'другую': 531,
#  'просьбой': 1779,
#  'эта скорость': 2410,
#  'не принимает': 1063,
#  'нареканий скорости': 985,
#  'обещали': 1175,
#  'минуты смс': 875,
#  'идут': 647,
#  'планирую': 1445,
#  'деньги не': 454,
#  'обновления не': 1194,
#  'оператор службы': 1233,
#  'фз 152': 2358,
#  'изменить': 654,
#  'район': 1843,
#  'центре': 2387,
#  '450': 100,
#  'отписаться': 1320,
#  'wi': 152,
#  'подключил услугу': 1517,
#  'сменить номер': 2030,
#  'еду': 534,
#  'https': 129,
#  'доброй': 483,
#  'сколько': 1989,
#  'этих': 2414,
#  'использование': 690,
#  '27': 66,
#  'остатки пакета': 1277,
#  'основании': 1260,
#  'выйти': 358,
#  'моему номеру': 940,
#  '50р': 110,
#  'привет': 1687,
#  'крайне': 795,
#  'доп': 504,
#  'пытался': 1806,
#  'просто': 1775,
#  'написано': 979,
#  'активации': 192,
#  'списание': 2113,
#  'переноса': 1407,
#  'сняли': 2063,
#  'минуту': 869,
#  'получить детализацию': 1583,
#  'связано': 1931,
#  'лично': 811,
#  'платные подписки': 1463,
#  'денежных': 447,
#  'июня': 710,
#  'могу дозвониться': 901,
#  'тел': 2232,
#  'нагрузках сеть': 967,
#  'дома': 497,
#  'система': 1978,
#  'услуги': 2327,
#  'городской номер': 393,
#  'прошу': 1793,
#  'почты': 1658,
#  'списанные средства': 2120,
#  'могу': 899,
#  'пополнен': 1620,
#  'решила': 1871,
#  'видит': 280,
#  'деньги интернет': 450,
#  'платой': 1470,
#  'вернуться': 268,
#  'начали': 999,
#  'звонков': 611,
#  'территории': 2252,
#  'могут дозвониться': 921,
#  'заказал': 562,
#  'две': 428,
#  'зайти личный': 558,
#  'сумму': 2169,
#  'номера теле2': 1150,
#  'положила': 1570,
#  'осталась': 1268,
#  'пришло сообщение': 1737,
#  'тариф не': 2205,
#  'номеру 611': 1160,
#  'пользоваться интернетом': 1591,
#  'платеж': 1451,
#  'отключать': 1290,
#  'период': 1425,
#  'краснодарском': 798,
#  'мобильным': 893,
#  'абоненту': 181,
#  'менять': 849,
#  'остатки': 1275,
#  'падать': 1361,
#  'вернуть списанные': 266,
#  'не происходит': 1069,
#  'нагрузках': 966,
#  'баланс': 196,
#  'услуг': 2318,
#  'одной': 1223,
#  'выдает': 351,
#  'интернет стал': 674,
#  'хотя не': 2373,
#  'якобы подписку': 2436,
#  'снова': 2061,
#  'весь': 271,
#  'приложении не': 1699,
#  'сколько стоить': 1991,
#  'перевели': 1389,
#  'мог': 895,
#  'номер': 1139,
#  'картой': 740,
#  'развлечения': 1827,
#  'мое': 926,
#  'слабый': 2007,
#  'размере': 1832,
#  'покупке установке': 1561,
#  'номера xx': 1148,
#  'не приходят': 1065,
#  'зайти': 557,
#  'мелодия': 843,
#  'предоставить': 1678,
#  'деньги телефон': 463,
#  'надпись': 972,
#  'тарифному': 2219,
#  'приходит': 1716,
#  'плохо': 1477,
#  'подключения': 1508,
#  'переносе': 1408,
#  'гудок': 397,
#  'этому': 2429,
#  'каждый': 720,
#  'информация': 689,
#  'другому оператору': 530,
#  'находясь': 993,
#  'рф': 1896,
#  'менять оператора': 850,
#  'частности': 2391,
#  'подписку': 1536,
#  'внесла': 293,
#  '300р': 81,
#  'ждать': 545,
#  '399': 90,
#  'пользование': 1588,
#  'это исправить': 2418,
#  'цена': 2383,
#  'пришел': 1730,
#  'получается': 1575,
#  'связь не': 1941,
#  'новый': 1135,
#  'остатке': 1274,
#  'месяцев': 860,
#  'никуда не': 1129,
#  'позвонил': 1548,
#  'высоких расходов': 364,
#  'беспредельно чёрный': 219,
#  'связаться': 1932,
#  'пакетов': 1371,
#  'моему': 939,
#  'симкарту': 1974,
#  'ужасно': 2293,
#  'не перенеслись': 1040,
#  'сотрудник': 2094,
#  'отключил': 1297,
#  'положил деньги': 1569,
#  'интернет трафика': 677,
#  'роспотребнадзор': 1876,
#  'край': 794,
#  'неудобно': 1110,
#  'такая ситуация': 2189,
#  'заказывала': 569,
#  'интернета исчерпания': 680,
#  'беспредельно черный': 218,
#  'исходящие звонки': 698,
#  'обновить': 1191,
#  'не нужен': 1029,
#  'доступ': 512,
#  'вай': 232,
#  'основной': 1261,
#  'пр': 1668,
#  'другого человека': 526,
#  'городе': 391,
#  'прошлого': 1788,
#  'обращаться': 1205,
#  'часто': 2392,
#  'отправляется': 1329,
#  'старую': 2152,
#  'перевести деньги': 1391,
#  '400 руб': 96,
#  'благодарен': 222,
#  'номер который': 1142,
#  '19': 43,
#  'это такое': 2428,
#  '290': 70,
#  'начал': 997,
#  'здравствуйте хотелось': 635,
#  'заплатил': 579,
#  'связь': 1939,
#  'никаких': 1120,
#  'какую': 735,
#  'media': 134,
#  'минуты интернет': 873,
#  'произвести': 1757,
#  'даче': 426,
#  '400 рублей': 97,
#  '35': 85,
#  'интернет трафик': 676,
#  'нужен интернет': 1167,
#  'отправляла': 1331,
#  'настройках': 988,
#  '17': 40,
#  'медленно': 841,
#  'руб месяц': 1884,
#  'подключен тариф': 1501,
#  'изменился': 653,
#  'всем': 334,
#  'поступили': 1653,
#  'месяца': 857,
#  'не подключал': 1045,
#  'сих пор': 1983,
#  'отвратительно': 1287,
#  'телефону': 2250,
#  'не пользовался': 1055,
#  'никто': 1126,
#  'пытаюсь': 1807,
#  'могли': 897,
#  'могу получить': 912,
#  'не хотелось': 1079,
#  'tele2 ru': 144,
#  'тому': 2259,
#  'сбой': 1915,
#  'регистрации': 1861,
#  '155': 38,
#  'плохая': 1475,
#  'неоднократно': 1100,
#  '11': 24,
#  'вашей компании': 241,
#  'этим номером': 2413,
#  'ошибочно': 1358,
#  'могу войти': 900,
#  'ежедневно': 535,
#  'интернете это': 683,
#  'инет': 663,
#  '30 гб': 74,
#  'другому': 529,
#  'решения': 1869,
#  'переход тариф': 1416,
#  'своим': 1923,
#  'пришла смс': 1732,
#  'подключал': 1493,
#  'подключено': 1512,
#  'смс номер': 2044,
#  'покрытие': 1558,
#  'перенести номер': 1404,
#  ...}

# %%
X_train_tfidf.shape, X_test_tfidf.shape
# Out:
# ((90296, 2438), (10033, 2438))

# %%
# fit logistic regression 
ls = LogisticRegression(solver='saga', verbose=1, n_jobs=-1)
ls.fit(X_train_tfidf, y_train_labels)
# Out:
# convergence after 18 epochs took 32 seconds
# convergence after 18 epochs took 32 seconds
# convergence after 19 epochs took 34 seconds
# convergence after 19 epochs took 34 seconds
# convergence after 20 epochs took 36 seconds
# convergence after 21 epochs took 37 seconds
# convergence after 21 epochs took 37 seconds
# convergence after 21 epochs took 37 seconds
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:   37.5s remaining:   14.0s
# convergence after 17 epochs took 10 seconds
# convergence after 21 epochs took 8 seconds
# convergence after 24 epochs took 10 seconds
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:   42.8s finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='saga', tol=0.0001,
#           verbose=1, warm_start=False)

# %%
# check accuracy of model on test set 
y_hat = ls.predict(X_test_tfidf)
acc_test = np.mean(y_hat==y_test_labels)

print('Accuracy on test data:', acc_test)
# Out:
# Accuracy on test data: 0.6052028306588259

# %% [markdown]
# # Visualization of predictions

# %%
def show_examples(id_example):
    
    text = X_test.reset_index(drop=True).iloc[id_example]
    predicted_label = le.inverse_transform(y_hat[id_example])
    true_label = le.inverse_transform(y_test_labels[id_example])

    print('Id:', id_example)
    print('True label:', true_label)
    print('Predicted label:', predicted_label)
    #print('Text:\n', text)
    display(eli5.show_prediction(ls, 
                         X_test.reset_index(drop=True).iloc[id_example], 
                         vec=tfidf,
                         #feature_names=list(tfidf.vocabulary_),
                         target_names=list(le.classes_),
                         targets=[predicted_label]))

# %%
# have a look at examples of text classification 
for idd in [0, 16, 2018, 10002, 10024]:
    show_examples(idd)
# Out:
# Id: 0
# True label: прочее
# Predicted label: прочее
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=прочее
#
# </b>
#
#
#     (probability <b>0.431</b>, score <b>0.012</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.864
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.851
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 98.01%); opacity: 0.80" title="0.005">сегодня</span><span style="opacity: 0.80"> мне сменили </span><span style="background-color: hsl(0, 100.00%, 90.72%); opacity: 0.82" title="-0.042">оператора</span><span style="opacity: 0.80"> с yota на </span><span style="background-color: hsl(120, 100.00%, 84.77%); opacity: 0.85" title="0.085">теле2</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 90.41%); opacity: 0.83" title="0.044">номер</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.37%); opacity: 0.85" title="-0.088">остался</span><span style="opacity: 0.80"> прежним (</span><span style="background-color: hsl(120, 100.00%, 79.72%); opacity: 0.88" title="0.128">перенесли</span><span style="opacity: 0.80"> с yota). моя </span><span style="background-color: hsl(120, 100.00%, 84.47%); opacity: 0.85" title="0.087">проблема</span><span style="opacity: 0.80"> заключается в том, что я скачала </span><span style="background-color: hsl(120, 100.00%, 83.30%); opacity: 0.86" title="0.097">приложение</span><span style="opacity: 0.80"> «мой </span><span style="background-color: hsl(120, 100.00%, 66.49%); opacity: 0.96" title="0.262">теле</span><span style="opacity: 0.80"> 2» и </span><span style="background-color: hsl(0, 100.00%, 88.73%); opacity: 0.83" title="-0.055">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.70%); opacity: 0.81" title="0.010">могу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 77.74%); opacity: 0.89" title="-0.146">зайти</span><span style="opacity: 0.80"> в него. </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.337">смс</span><span style="opacity: 0.80"> на мой </span><span style="background-color: hsl(120, 100.00%, 93.84%); opacity: 0.81" title="0.023">номер</span><span style="opacity: 0.80">     </span><span style="background-color: hsl(0, 100.00%, 85.97%); opacity: 0.84" title="-0.075">xx</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.93%); opacity: 0.85" title="0.084">xx</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.67%); opacity: 0.81" title="0.024">пишет</span><span style="opacity: 0.80">..</span><span style="background-color: hsl(120, 100.00%, 77.74%); opacity: 0.89" title="0.146">отправить</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.91%); opacity: 0.84" title="-0.061">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.66%); opacity: 0.85" title="0.078">возможно</span><span style="opacity: 0.80"> </span>
#     </p>
# Id: 16
# True label: мобильныйИнтернет
# Predicted label: мобильныйИнтернет
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=мобильныйИнтернет
#
# </b>
#
#
#     (probability <b>0.463</b>, score <b>-0.429</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.667
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">добрый день. занимаемся строительством частного жилья в г.краснодар. </span><span style="background-color: hsl(0, 100.00%, 93.71%); opacity: 0.81" title="-0.065">хотелось</span><span style="opacity: 0.80"> бы </span><span style="background-color: hsl(0, 100.00%, 93.55%); opacity: 0.81" title="-0.067">вместе</span><span style="opacity: 0.80"> со строительством </span><span style="background-color: hsl(120, 100.00%, 94.15%); opacity: 0.81" title="0.058">дома</span><span style="opacity: 0.80"> оказывать </span><span style="background-color: hsl(0, 100.00%, 89.96%); opacity: 0.83" title="-0.126">услугу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 65.20%); opacity: 0.96" title="0.743">3g</span><span style="opacity: 0.80">-</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.907">4g</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 63.86%); opacity: 0.97" title="0.785">интернета</span><span style="opacity: 0.80"> &quot;под ключ&quot;. существуют ли у вас корпоративные или индивидуальные </span><span style="background-color: hsl(0, 100.00%, 83.21%); opacity: 0.86" title="-0.263">тарифы</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.16%); opacity: 0.81" title="0.044">которые</span><span style="opacity: 0.80"> мы </span><span style="background-color: hsl(120, 100.00%, 94.25%); opacity: 0.81" title="0.057">могли</span><span style="opacity: 0.80"> бы устанавливать клиентам </span><span style="background-color: hsl(0, 100.00%, 93.55%); opacity: 0.81" title="-0.067">вместе</span><span style="opacity: 0.80"> с оборудованием? нас интересуют в первую очередь </span><span style="background-color: hsl(0, 100.00%, 83.21%); opacity: 0.86" title="-0.263">тарифы</span><span style="opacity: 0.80"> с максимально возможным </span><span style="background-color: hsl(0, 100.00%, 98.25%); opacity: 0.80" title="-0.010">безлимитным</span><span style="opacity: 0.80"> трафиком. </span><span style="background-color: hsl(120, 100.00%, 97.19%); opacity: 0.80" title="0.020">можем</span><span style="opacity: 0.80"> ли мы заключить с </span><span style="background-color: hsl(120, 100.00%, 97.35%); opacity: 0.80" title="0.019">вами</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.81%); opacity: 0.85" title="-0.228">договор</span><span style="opacity: 0.80"> и сотрудничать в </span><span style="background-color: hsl(120, 100.00%, 86.60%); opacity: 0.84" title="0.190">данном</span><span style="opacity: 0.80"> направлении?</span>
#     </p>
# Id: 2018
# True label: подключенныеУслуги
# Predicted label: подключенныеУслуги
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=подключенныеУслуги
#
# </b>
#
#
#     (probability <b>0.671</b>, score <b>1.046</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.763
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.717
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">добрый день. </span><span style="background-color: hsl(120, 100.00%, 94.09%); opacity: 0.81" title="0.126">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.73%); opacity: 0.85" title="0.443">могу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.933">отключить</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 71.75%); opacity: 0.92" title="1.176">платную</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.29%); opacity: 0.88" title="0.755">услугу</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 96.82%); opacity: 0.81" title="0.052">которая</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.16%); opacity: 0.81" title="0.124">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.82%); opacity: 0.83" title="0.313">знаю</span><span style="opacity: 0.80"> как </span><span style="background-color: hsl(120, 100.00%, 87.54%); opacity: 0.84" title="0.365">подключилась</span><span style="opacity: 0.80">.</span>
#     </p>
# Id: 10002
# True label: мобильныйИнтернет
# Predicted label: прочее
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=прочее
#
# </b>
#
#
#     (probability <b>0.478</b>, score <b>-0.668</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.183
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.851
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 96.30%); opacity: 0.81" title="-0.028">здравствуйте</span><span style="opacity: 0.80">. что </span><span style="background-color: hsl(120, 100.00%, 88.65%); opacity: 0.83" title="0.138">происходит</span><span style="opacity: 0.80"> со </span><span style="background-color: hsl(120, 100.00%, 68.48%); opacity: 0.94" title="0.595">связью</span><span style="opacity: 0.80">?!!! я с пяти вечера </span><span style="background-color: hsl(0, 100.00%, 83.16%); opacity: 0.86" title="-0.243">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.14%); opacity: 0.82" title="-0.097">могу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.10%); opacity: 0.82" title="-0.098">воспользоваться</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-0.836">интернетом</span><span style="opacity: 0.80">!!!!! в </span><span style="background-color: hsl(120, 100.00%, 88.97%); opacity: 0.83" title="0.133">приложение</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.72%); opacity: 0.85" title="0.192">теле</span><span style="opacity: 0.80"> 2 </span><span style="background-color: hsl(0, 100.00%, 97.40%); opacity: 0.80" title="-0.017">раза</span><span style="opacity: 0.80">  </span><span style="background-color: hsl(120, 100.00%, 86.35%); opacity: 0.84" title="0.180">10</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.75%); opacity: 0.82" title="0.088">удалось</span><span style="opacity: 0.80"> попасть</span>
#     </p>
# Id: 10024
# True label: мобильныйИнтернет
# Predicted label: мобильныйИнтернет
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=мобильныйИнтернет
#
# </b>
#
#
#     (probability <b>0.500</b>, score <b>-0.467</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.630
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.097
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 97.61%); opacity: 0.80" title="0.015">здравствуйте</span><span style="opacity: 0.80">.я </span><span style="background-color: hsl(0, 100.00%, 91.10%); opacity: 0.82" title="-0.097">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.07%); opacity: 0.84" title="-0.166">могу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.17%); opacity: 0.80" title="0.003">понять</span><span style="opacity: 0.80"> куда </span><span style="background-color: hsl(120, 100.00%, 84.90%); opacity: 0.85" title="0.207">уходит</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 65.19%); opacity: 0.96" title="0.683">трафик</span><span style="opacity: 0.80">(</span><span style="background-color: hsl(0, 100.00%, 95.98%); opacity: 0.81" title="-0.031">40</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 65.02%); opacity: 0.97" title="0.688">мб</span><span style="opacity: 0.80"> за </span><span style="background-color: hsl(120, 100.00%, 81.30%); opacity: 0.87" title="0.281">пол</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.88%); opacity: 0.83" title="0.117">часа</span><span style="opacity: 0.80">),если </span><span style="background-color: hsl(0, 100.00%, 96.02%); opacity: 0.81" title="-0.031">кроме</span><span style="opacity: 0.80"> безлимитного </span><span style="background-color: hsl(120, 100.00%, 96.01%); opacity: 0.81" title="0.031">приложения</span><span style="opacity: 0.80"> &quot;</span><span style="background-color: hsl(120, 100.00%, 78.46%); opacity: 0.88" title="0.344">вконтакте</span><span style="opacity: 0.80">&quot; я </span><span style="background-color: hsl(120, 100.00%, 99.08%); opacity: 0.80" title="0.004">использую</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.98%); opacity: 0.83" title="0.115">очень</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.57%); opacity: 0.85" title="-0.194">мало</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.833">интернета</span><span style="opacity: 0.80">. и за </span><span style="background-color: hsl(0, 100.00%, 61.92%); opacity: 0.99" title="-0.777">звонки</span><span style="opacity: 0.80"> на </span><span style="background-color: hsl(0, 100.00%, 77.44%); opacity: 0.89" title="-0.368">теле2</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.20%); opacity: 0.83" title="-0.112">деньги</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.67%); opacity: 0.81" title="0.060">списываются</span><span style="opacity: 0.80"> со </span><span style="background-color: hsl(0, 100.00%, 77.44%); opacity: 0.89" title="-0.368">счета</span><span style="opacity: 0.80">.</span>
#     </p>
