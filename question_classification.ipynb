# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import stopwords

# %% [markdown]
# # Read data

# %%
data = pd.read_csv('D:/tele2_data_hack/email_reports.csv')
print(data.shape)
# Out:
# (125938, 10)

# %%
data.head()
# Out:
#      SENDER_ID    SENDER_EMAIL OPERATOR_ID                   ACCEPTOR  \
# 0   token_7747  xxxx@yandex.ru    token_48        spb.vopros@tele2.ru
# 1  token_14226    xxxx@mail.ru    token_50    Saransk.Vopros@tele2.ru
# 2  token_23942    xxxx@mail.ru     token_3     rostov.vopros@tele2.ru
# 3  token_18368    xxxx@mail.ru    token_53  krasnodar.vopros@tele2.ru
# 4  token_21039    xxxx@mail.ru    token_34   kostroma.vopros@tele2.ru
#
#                  SUBJECT        To.queue.time   agent.receive.time  \
# 0         Обратная связь  2088-06-17 02:31:32  2088-06-18 19:48:26
# 1  Re[2]: Обратная связь  2088-06-17 02:31:52  2088-06-18 18:43:45
# 2         Обратная связь  2088-06-17 02:33:14  2088-06-18 18:43:45
# 3         Обратная связь  2088-06-17 02:33:36  2088-06-18 19:49:10
# 4         Обратная связь  2088-06-17 02:33:56  2088-06-18 19:49:17
#
#     treatment.end.time                                            CONTENT  \
# 0  2088-06-18 20:24:59  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 1  2088-06-18 18:58:43    \r\nвся необходимая информация отображена в ...
# 2  2088-06-18 18:47:06  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 3  2088-06-18 19:53:57  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 4  2088-06-18 19:59:48  Тело письма\r\n\r\nОтметьте, в каком регионе В...
#
#                                           ANSWERTEXT
# 0  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx!\r\n\r...
# 1  Здравствуйте, xxxxx xxxxx xxxxx!\r\nБлагодарим...
# 2  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx!\r\nБл...
# 3  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx! ¦\r\n...
# 4  \r\n\r\nАлександр, доброго времени суток! ;)\r...

# %% [markdown]
# # determine fraction of each problem

# %%
# for training classifier use only letters for support 
print(data.shape)
data = data[data['CONTENT'].apply(lambda x: 'Тело письма' in str(x))].reset_index(drop=True)
print(data.shape)
# Out:
# (125938, 10)
# (102898, 10)

# %% [markdown]
# ### Get question from user and topic of this question

# %%
def get_topic(x):
    ret = ''
    try:
        ret = x.split('Выберите тему обращения: ')[1].split('\r')[0]
    except:
        pass
    return ret

def get_question(x):
    ret = ''
    try:
        ret = x.split('Выберите тему обращения: ')[1].split('\r')[1].split('\nЗадайте ваш вопрос или опишите проблему: ')[1]
    except:
        pass
    return ret


data['topic'] = data['CONTENT'].apply(lambda x: get_topic(x))
data['question'] = data['CONTENT'].apply(lambda x: get_question(x))

# %% [markdown]
# ### Statistics of topics

# %%
temp = data[['topic','CONTENT']].groupby('topic').agg('count').reset_index()
temp = temp.rename_axis({'CONTENT':'Number of questions'},axis=1)
num_q = np.sum(temp['Number of questions'])
temp = temp[temp['Number of questions']>1200].reset_index(drop=True)

temp['Topic fraction'] = temp['Number of questions'] / num_q * 100
print('Most popular topics fraction: ', np.sum(temp['Topic fraction']), '%')
# Out:
# Most popular topics fraction:  97.50335283484615 %
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Using 'rename_axis' to alter labels is deprecated. Use '.rename' instead

# %%
temp.sort_values(by='Topic fraction', ascending=False)
# Out:
#                                   topic  Number of questions  Topic fraction
# 8                                прочее                24434       23.745845
# 10                        тарифыИУслуги                18770       18.241365
# 3                     мобильныйИнтернет                15918       15.469688
# 6                    подключенныеУслуги                 9112        8.855371
# 2                         личныйКабинет                 7379        7.171179
# 9              роумингИЗонаОбслуживания                 6732        6.542401
# 7   поступлениеПлатежейОшибочныеПлатежи                 6045        5.874750
# 1            детализацияСчётаИлиЗвонков                 5474        5.319831
# 0      блокировкаИРазблокировкаSimКарты                 2412        2.344069
# 5                     подключениеКTele2                 2398        2.330463
# 4                   переносНомераВTele2                 1655        1.608389

# %%
most_freq_topics = list(temp['topic'])

# %%
# keep only freq topics 
data = data[data['topic'].apply(lambda x: x in most_freq_topics)].reset_index(drop=True)

# %% [markdown]
# ### Prepare data for test classification

# %%
X_train, X_test, y_train, y_test = train_test_split(data['question'], data['topic'], 
                                                    shuffle=False, 
                                                    test_size=0.1)

# %%
le = LabelEncoder()
y_train_labels = le.fit_transform(y_train)
y_test_labels = le.transform(y_test)

# %%
xs_seq = []
for n_x in np.arange(10,2,-1):
    xs_seq.append('x'*n_x)
    
def preprocess_string(x):
    for xs in xs_seq:
        x = re.sub(xs, ' ', x)
    return x

X_train = X_train.apply(lambda x: preprocess_string(x))
X_test = X_test.apply(lambda x: preprocess_string(x))

# %%
stopWords = set(stopwords.words('russian'))
stopWords = list(stopWords)
stopWords = stopWords + ['вечер', 'добрый', 'день', 'скажите', 'пожалуйста', 'спасибо', 'ли', 'почему', 'вопрос']
stopWords.remove('не')
stopWords = set(stopWords)
print('Number of stop words:', len(stopWords))
# Out:
# Number of stop words: 158

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 2), min_df=100, max_df=0.99, stop_words=stopWords)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
tfidf.vocabulary_
# Out:
# {'основной': 1261,
#  'случилось': 2022,
#  'не буду': 1006,
#  'прошлого': 1788,
#  'приложений': 1701,
#  'не перенесли': 1039,
#  'смогу': 2037,
#  'произошло': 1759,
#  'смене': 2026,
#  'контент': 769,
#  'свое': 1917,
#  'говорит': 384,
#  'система': 1978,
#  'приложения': 1702,
#  'связи этим': 1938,
#  'оплатил': 1243,
#  'услугу': 2332,
#  '45': 99,
#  'здравствуйте прошу': 629,
#  'заранее благодарю': 585,
#  'однако': 1220,
#  'оплата': 1241,
#  'не хватает': 1077,
#  'живу': 547,
#  'фото': 2359,
#  'домашнем': 500,
#  'получить': 1582,
#  'обмена': 1185,
#  'оператора': 1234,
#  'операторы': 1240,
#  'прошу отключить': 1797,
#  'сняли 30': 2064,
#  'купил': 804,
#  'отправляется': 1329,
#  'никак не': 1118,
#  'своему': 1921,
#  'ндс отключения': 1004,
#  'рассмотреть': 1850,
#  'непонятно': 1101,
#  'равно': 1823,
#  'какова': 729,
#  'не заказывала': 1018,
#  'работе': 1820,
#  'позвонить не': 1551,
#  'билайн': 220,
#  'двух': 429,
#  'ведома': 254,
#  'месяцев': 860,
#  'жалобу центральный': 544,
#  'звонят': 615,
#  'тарифном': 2217,
#  'приложение пишет': 1694,
#  'нужна': 1168,
#  'связи не': 1936,
#  'плату': 1471,
#  'могу пополнить': 916,
#  'дозвониться': 490,
#  'данной ситуации': 411,
#  'могли снять': 898,
#  'других': 522,
#  'сайта': 1899,
#  'запрет': 582,
#  'вашу': 249,
#  'средства якобы': 2141,
#  'денежные средства': 446,
#  'тариф разговор': 2208,
#  'ввожу': 252,
#  'приходят сообщения': 1724,
#  'списывать': 2129,
#  '400': 95,
#  'андроид': 195,
#  'мобильного': 883,
#  'обращения': 1208,
#  'вашими': 246,
#  'текущий': 2231,
#  'звонили': 601,
#  'взял': 273,
#  'сеть': 1957,
#  'смотреть': 2038,
#  'пор не': 1638,
#  'уведомление': 2283,
#  'не помню': 1057,
#  'подключен тариф': 1501,
#  'банковской': 203,
#  'поддерживает': 1486,
#  'тарифа не': 2211,
#  'отправила': 1322,
#  'пишет не': 1436,
#  'входа': 341,
#  'купила': 805,
#  'подключить услугу': 1529,
#  'приложения теле2': 1704,
#  'ответьте': 1285,
#  '06': 8,
#  'отключили': 1299,
#  '30 руб': 75,
#  'приходит детализация': 1717,
#  'личному': 816,
#  'сделали': 1947,
#  'оформлен': 1345,
#  'ввести': 250,
#  'включается': 284,
#  'пришлите': 1734,
#  'тк': 2258,
#  'мобильная': 881,
#  'минус': 862,
#  'зоне': 643,
#  'успешно': 2336,
#  'ошибочный': 1359,
#  'отключение': 1293,
#  'также': 2190,
#  'поменяли': 1598,
#  'проседание': 1770,
#  'сделала': 1946,
#  'платную': 1459,
#  'дней назад': 472,
#  'вашим': 245,
#  'подключает': 1490,
#  'очень плохо': 1350,
#  'пользоваться не': 1592,
#  '02': 4,
#  'вернуть денежные': 262,
#  'доброе утро': 482,
#  'имеется': 656,
#  'могу найти': 904,
#  'мегабайты': 838,
#  '08': 12,
#  'своём': 1930,
#  'связь интернет': 1940,
#  'ютуб': 2430,
#  'передачи': 1396,
#  'мелодии': 842,
#  'сети теле2': 1956,
#  'прошу сообщить': 1805,
#  'условиям': 2315,
#  'вк': 283,
#  'личный кабинет': 819,
#  'экране': 2402,
#  'biz': 121,
#  'списаны': 2122,
#  '03': 5,
#  'внесена': 292,
#  'подписывался': 1540,
#  'стоимость': 2155,
#  'московской области': 957,
#  'вместе': 288,
#  'заказала детализацию': 564,
#  'подряд': 1541,
#  'разберитесь': 1825,
#  'списываются деньги': 2134,
#  'положила': 1570,
#  'заказал': 562,
#  'сохранить': 2098,
#  'расходы': 1856,
#  'пользования': 1589,
#  'помогите': 1606,
#  'внёс': 298,
#  'помогает': 1605,
#  'приходится': 1720,
#  'регул': 1862,
#  'могу перейти': 909,
#  'мои деньги': 945,
#  '13': 27,
#  'соответственно': 2089,
#  'списываются': 2133,
#  'возможно отправить': 303,
#  '24': 57,
#  '250р': 63,
#  'интернет оператора': 670,
#  'факту': 2353,
#  'остаток': 1279,
#  'переходить': 1419,
#  'пользование': 1588,
#  'veseluxa com': 151,
#  'гб минуты': 374,
#  'media cloud': 135,
#  'выше позже': 369,
#  'причина': 1726,
#  'обнаружила': 1189,
#  'нахождении': 994,
#  '2g': 71,
#  '07': 10,
#  'давно': 400,
#  'полном': 1565,
#  'ближайшее': 224,
#  '300': 78,
#  'стоят': 2164,
#  'пропали': 1769,
#  'звонки смс': 609,
#  'причине моих': 1728,
#  'модема': 924,
#  'обл': 1179,
#  'входа личный': 342,
#  'скорости договоре': 1996,
#  'интернет': 665,
#  'очень чёрный': 1353,
#  'службу': 2015,
#  'сумме': 2168,
#  'устраивает': 2341,
#  '15': 29,
#  'никакого': 1123,
#  'последнее время': 1643,
#  'каждый': 720,
#  'puk': 136,
#  'супер': 2171,
#  'неоднократно': 1100,
#  'является': 2431,
#  'говорилось возможных': 383,
#  'других операторов': 523,
#  'сбой': 1915,
#  'возврат': 300,
#  'обновления': 1193,
#  'youtube': 164,
#  'отвечает': 1286,
#  'помогите решить': 1608,
#  'суток': 2175,
#  '200р': 52,
#  'тт': 2274,
#  'помощь': 1611,
#  'оказалось': 1226,
#  'медленно': 841,
#  'пин': 1430,
#  'не переносятся': 1041,
#  'менял': 848,
#  'дату': 424,
#  'заблокированы': 551,
#  'москвы': 955,
#  'неиспользованные': 1094,
#  'точнее': 2260,
#  'яндекс': 2437,
#  'нареканий скорости': 985,
#  'это происходит': 2425,
#  'минуты интернет': 873,
#  'сообщить': 2088,
#  'номеру xx': 1161,
#  'настроить': 987,
#  'банка': 202,
#  'связь не': 1941,
#  'моего телефона': 934,
#  'подключают': 1497,
#  'прошу': 1793,
#  'домашнем регионе': 501,
#  'ваши': 244,
#  'договоре': 488,
#  'пополнил счёт': 1626,
#  'этому': 2429,
#  'компанию': 764,
#  'не показывает': 1051,
#  'тарифа онлайн': 2212,
#  'нахожусь роуминге': 996,
#  'разы': 1841,
#  'изменили': 651,
#  'xx xxd_': 160,
#  '270': 67,
#  'пополнить счет': 1633,
#  'пароль входа': 1377,
#  'писал': 1431,
#  'сотрудник': 2094,
#  'просмотре': 1774,
#  'никакие': 1119,
#  'телефона xx': 2243,
#  'связи теле2': 1937,
#  'число': 2399,
#  'это отключить': 2422,
#  'прошу дать': 1795,
#  'сеть не': 1958,
#  'соединения': 2082,
#  'личного кабинета': 813,
#  'пакеты': 1372,
#  'предложение': 1674,
#  'июль': 705,
#  'указано': 2300,
#  'моего согласия': 930,
#  '50 смс': 105,
#  'лимит': 809,
#  'вашем': 242,
#  'прошлом': 1790,
#  'гигобайты': 379,
#  'вернуться': 268,
#  'видео': 277,
#  'ул': 2302,
#  'гб интернета': 373,
#  'снимаются деньги': 2060,
#  'данные': 416,
#  'ежемесячно': 536,
#  'идет': 646,
#  'здравствуйте хотелось': 635,
#  'симку': 1977,
#  'здравствуйте могу': 619,
#  'интернет вообще': 666,
#  'подключить': 1525,
#  'зайти': 557,
#  'баланс': 196,
#  'центре': 2387,
#  'здравствуйте возникла': 617,
#  'нул': 1174,
#  'теле2 пишет': 2238,
#  'приложением': 1697,
#  'подключена подписка': 1504,
#  'номера xx': 1148,
#  'телефонов': 2248,
#  'используется': 693,
#  'это исправить': 2418,
#  'снимаете': 2051,
#  'грузится': 396,
#  'краснодарский край': 797,
#  'помогите разобраться': 1607,
#  'исчерпания определенного': 702,
#  '00': 0,
#  'данному': 413,
#  'фай': 2352,
#  'прекратить': 1684,
#  'придется': 1689,
#  'редко': 1864,
#  'средства размере': 2140,
#  'заблокировать': 552,
#  'менять оператора': 850,
#  'везде': 256,
#  'заказать': 565,
#  'поддержку': 1489,
#  'не понимаю': 1059,
#  'программы': 1753,
#  'электронной': 2406,
#  'лицевого': 810,
#  'информация': 689,
#  'звонки не': 608,
#  'плохая': 1475,
#  'стоит': 2157,
#  'положили': 1572,
#  'зайти личный': 558,
#  'самостоятельно': 1909,
#  'откуда': 1312,
#  'номера теле2': 1150,
#  'интернет звонки': 668,
#  'картой': 740,
#  'салон': 1902,
#  'поддержки': 1487,
#  '10гб': 23,
#  'электронную почту': 2408,
#  'экстренные вызовы': 2404,
#  '10 рублей': 17,
#  'звонках': 604,
#  'пользуется': 1593,
#  'перестал работать': 1412,
#  'план': 1441,
#  'нечаянно': 1111,
#  'дня': 475,
#  'каким образом': 727,
#  'положить': 1574,
#  'сбербанка': 1914,
#  'слишком': 2014,
#  'подключено': 1512,
#  'услугу гудок': 2333,
#  'московской': 956,
#  'эл': 2405,
#  '250': 60,
#  'каждые': 719,
#  'сделал': 1945,
#  'не перенеслись': 1040,
#  'постоянные': 1650,
#  'вновь': 296,
#  'не номер': 1028,
#  'личном кабинете': 815,
#  '17': 40,
#  'какое': 731,
#  'пару': 1380,
#  'абонентом теле2': 173,
#  'счету': 2180,
#  'вместо': 289,
#  'приходить': 1721,
#  'некоторое': 1095,
#  'подписки': 1534,
#  'приостановлено': 1713,
#  'номеру': 1159,
#  'поменять номер': 1601,
#  'открывается': 1310,
#  'выдаёт': 352,
#  'надоело': 971,
#  'такого не': 2196,
#  'запрос': 583,
#  'скорости': 1995,
#  '90': 119,
#  'поменяла': 1597,
#  'сделайте': 1944,
#  'управление': 2305,
#  'входе': 343,
#  'оплатила': 1244,
#  'проверьте': 1752,
#  'года': 387,
#  'отлично': 1313,
#  'отпуск': 1337,
#  'плата': 1450,
#  'разобраться': 1835,
#  'написали': 978,
#  'якобы подписку': 2436,
#  'края': 800,
#  'баланс не': 197,
#  'мобильной': 887,
#  'персональных': 1428,
#  'не отправляется': 1034,
#  'минуты смс': 875,
#  'например': 983,
#  'доброе': 481,
#  'этих': 2414,
#  'высоких расходов': 364,
#  'интересует': 664,
#  'немогу': 1098,
#  'придётся': 1690,
#  'кабинет': 711,
#  'моих высоких': 948,
#  'понимание': 1613,
#  'получения': 1578,
#  'ммс': 876,
#  'частности': 2391,
#  'неверный': 1081,
#  'недель': 1087,
#  'списке': 2125,
#  'девушка': 430,
#  'мобильном приложении': 890,
#  'делала': 438,
#  'пределами': 1673,
#  'не имею': 1021,
#  'здравствуйте такая': 631,
#  '20bd': 53,
#  'заявку': 597,
#  '700': 116,
#  'не нужны': 1032,
#  'центральный': 2385,
#  'увидела': 2286,
#  'рублей не': 1890,
#  'кода': 757,
#  'мобильное': 885,
#  'фз': 2357,
#  'снимали': 2053,
#  'пришло': 1735,
#  'не доступен': 1015,
#  'детализацию': 467,
#  '4g': 101,
#  'счёта': 2183,
#  'приложения не': 1703,
#  'перевести': 1390,
#  'внести': 294,
#  'продолжаться': 1755,
#  'крым': 802,
#  'района': 1844,
#  'сами': 1906,
#  'заменить': 575,
#  'всем': 334,
#  'сих': 1982,
#  'банковскую карту': 206,
#  '600': 113,
#  'могу позвонить': 911,
#  'моего': 927,
#  'подписки не': 1535,
#  'отправлять': 1332,
#  'опция': 1259,
#  '400р': 98,
#  'деревне': 464,
#  'прошлом месяце': 1791,
#  'стоить': 2158,
#  'исправьте': 696,
#  'работало': 1816,
#  'рамках': 1846,
#  'использовать': 692,
#  'самое': 1907,
#  'уровне': 2309,
#  'второй месяц': 337,
#  'очередной': 1354,
#  'ул x000d_': 2303,
#  '00 00': 1,
#  'суд': 2166,
#  'нагрузках': 966,
#  'работает мобильный': 1811,
#  'пришло сообщение': 1737,
#  'июле': 704,
#  'сайт': 1898,
#  'взять обещанный': 275,
#  'оповещения': 1252,
#  'прошу решить': 1804,
#  'могу поменять': 914,
#  'личном': 814,
#  'чек': 2394,
#  'полное': 1564,
#  'стороны': 2163,
#  'платные услуги': 1464,
#  'отключен': 1291,
#  'крае': 793,
#  'номеру телефона': 1162,
#  'гб': 372,
#  'выдаёт ошибку': 353,
#  'tuboteka ru': 148,
#  'сказала': 1985,
#  'не получил': 1053,
#  'минуты не': 874,
#  'не хотелось': 1079,
#  'краснодарском крае': 799,
#  'имя': 661,
#  'регул x000d_': 1863,
#  'качество': 746,
#  'хочется': 2374,
#  'территории': 2252,
#  'срок': 2142,
#  'предложить': 1677,
#  'условию': 2311,
#  'получить пароль': 1584,
#  'tuboteka': 146,
#  'зона': 642,
#  'данный': 417,
#  'работать интернет': 1818,
#  'получить смс': 1585,
#  'предоставлен логин': 1680,
#  'оператора это': 1236,
#  '30 рублей': 76,
#  'наблюдается': 964,
#  'какому': 734,
#  'появилась': 1662,
#  '500мб': 109,
#  'могу': 899,
#  'новые': 1134,
#  'ограничение интернет': 1217,
#  'сделать детализацию': 1949,
#  'вопроса': 317,
#  '27': 66,
#  'конца недели': 775,
#  'получать': 1576,
#  'нигде не': 1114,
#  'случае': 2019,
#  'уважаемые': 2279,
#  'условиям тарифа': 2316,
#  'доступ': 512,
#  'информацию': 688,
#  'внес': 291,
#  'плохо ловит': 1478,
#  'поменял': 1596,
#  'отправляет': 1328,
#  'хотелось узнать': 2371,
#  'должна': 494,
#  'вопросу': 319,
#  'офис': 1341,
#  'центральный офис': 2386,
#  'данную услугу': 415,
#  'обещали': 1175,
#  'контента': 772,
#  'быстро': 231,
#  'обработку': 1196,
#  'обращаюсь': 1206,
#  'регистрации': 1861,
#  'здравствуйте моего': 620,
#  'поступают': 1651,
#  'минуту': 869,
#  'данную': 414,
#  'прошла': 1786,
#  'зоны': 644,
#  'место': 854,
#  'абонентскую': 179,
#  'точно': 2261,
#  'практически не': 1672,
#  'добавить': 477,
#  'ситуацию': 1980,
#  'сут ндс': 2173,
#  'несколько': 1105,
#  'подключение': 1506,
#  'каждого': 718,
#  'действует': 436,
#  'работает связь': 1814,
#  'здраствуйте': 637,
#  'иначе': 662,
#  'региона': 1859,
#  'написать': 980,
#  'сказал': 1984,
#  'гб не': 375,
#  'телефон не': 2241,
#  'роуминга': 1879,
#  'области': 1180,
#  'обновить': 1191,
#  'платный контент': 1466,
#  'код': 756,
#  'требует': 2269,
#  'пришло смс': 1736,
#  'могу сделать': 918,
#  'пополнила': 1627,
#  'скорее': 1993,
#  'перейду': 1398,
#  'нужны': 1173,
#  'нужен интернет': 1167,
#  'сверх': 1916,
#  'оставить': 1264,
#  'номер теле2': 1145,
#  'нагрузки сеть': 969,
#  'исчезли': 700,
#  '05': 7,
#  'отменить': 1314,
#  '30гб': 82,
#  'оператор службы': 1233,
#  'хочу подключить': 2378,
#  '70': 115,
#  'гигабайты': 377,
#  'пропадает': 1762,
#  'другого оператора': 525,
#  'вернуть деньги': 263,
#  'какие платные': 723,
#  'попытке': 1636,
#  'стало': 2149,
#  'вай': 232,
#  'позвонила': 1549,
#  'отключить не': 1305,
#  'месяца не': 858,
#  'покрытия': 1559,
#  '25': 59,
#  'написал': 977,
#  'пользуюсь': 1594,
#  'изменилось': 652,
#  'остатки': 1275,
#  'говорилось': 382,
#  'обращался': 1204,
#  'районе': 1845,
#  'отключить автоплатеж': 1303,
#  'wi fi': 153,
#  'перехода': 1417,
#  'кабинет пишет': 713,
#  'кабинете': 715,
#  'не работают': 1071,
#  'заплатить': 581,
#  'можем': 942,
#  'положила деньги': 1571,
#  'деньги счет': 459,
#  'правильно': 1670,
#  'платные': 1462,
#  'обновился': 1190,
#  'смс номер': 2044,
#  'работал': 1815,
#  'отключите': 1300,
#  'остаться': 1280,
#  'согласие': 2077,
#  'мобильный интернет': 892,
#  'доп': 504,
#  'писать': 1433,
#  'мобильным интернетом': 894,
#  'разобраться вернуть': 1836,
#  'онлайн': 1229,
#  'изменился': 653,
#  'пользовалась': 1586,
#  'списание средств': 2114,
#  'всей россии': 333,
#  'не давала': 1012,
#  'июля года': 707,
#  'телефоне не': 2247,
#  'банк': 201,
#  'сохранением номера': 2097,
#  'плану': 1446,
#  'стоимостью': 2156,
#  'пароль': 1375,
#  'проверить': 1751,
#  'хотела узнать': 2369,
#  'минут гб': 864,
#  'которые не': 787,
#  'это возможно': 2416,
#  '100 рублей': 20,
#  'пропадает сеть': 1764,
#  'могу отправить': 907,
#  'смс паролем': 2046,
#  'пользоваться': 1590,
#  'восстановится': 322,
#  'отключается': 1289,
#  'некоторое время': 1096,
#  'данное': 409,
#  'деньги не': 454,
#  'примерно': 1705,
#  'такая проблема': 2188,
#  'городской': 392,
#  'платежа': 1452,
#  'связано': 1931,
#  'старый тариф': 2154,
#  'снимаются': 2059,
#  'прошу предоставить': 1800,
#  'вашему': 243,
#  'не приходит': 1064,
#  'сут': 2172,
#  'мтс': 963,
#  'кабинет не': 712,
#  'пополнить баланс': 1632,
#  '100': 18,
#  'платежи': 1453,
#  'сайты': 1901,
#  '350 руб': 87,
#  'поставить': 1647,
#  'смс не': 2043,
#  'проблемы': 1747,
#  '350': 86,
#  'отправить смс': 1325,
#  '10': 14,
#  'якобы': 2435,
#  'деньги интернет': 450,
#  'удобно': 2291,
#  'подключена': 1502,
#  'подписок': 1538,
#  'не поступили': 1061,
#  '60 рублей': 112,
#  'проблем': 1739,
#  'перешла': 1421,
#  'замены': 576,
#  'подписку tuboteka': 1537,
#  'старую': 2152,
#  'подключать': 1496,
#  'отключила': 1298,
#  'давала': 399,
#  'делаю': 440,
#  '16': 39,
#  '35': 85,
#  'не причине': 1066,
#  '40': 94,
#  'действий': 432,
#  'не получается': 1052,
#  'карту': 741,
#  'которого': 779,
#  'разу': 1839,
#  'исчерпания': 701,
#  'вернуть обратно': 265,
#  'могу отключить': 906,
#  'iphone': 130,
#  'gprs': 127,
#  'минуты гигабайты': 872,
#  'адрес': 189,
#  'течение': 2254,
#  'связью': 1942,
#  'надеюсь': 970,
#  'выйти': 358,
#  'требуется': 2270,
#  'заказе': 567,
#  'это связано': 2426,
#  'заходила': 590,
#  'сменить оператора': 2031,
#  'подключал': 1493,
#  'хотела': 2368,
#  'платная услуга': 1457,
#  'вообще': 315,
#  'исходящих': 699,
#  'смена': 2025,
#  'должно': 495,
#  'подключите': 1524,
#  'отключения отправьте': 1295,
#  'которое': 780,
#  '300 рублей': 80,
#  'закончился': 573,
#  'пришлось': 1738,
#  'отключить платные': 1307,
#  'сотовой связи': 2093,
#  'прерывается': 1685,
#  'выходит': 367,
#  'карты нареканий': 744,
#  'приложение не': 1693,
#  'клиентов': 750,
#  'всей': 332,
#  'пробовал': 1749,
#  'услуги моего': 2329,
#  'дополнительные': 506,
#  'ведома согласия': 255,
#  'сообщение не': 2085,
#  'номере': 1154,
#  'опуститься увы': 1256,
#  '15 рублей': 32,
#  'сколько': 1989,
#  'недоступна': 1092,
#  'новый тариф': 1136,
#  'fi': 126,
#  'карте': 739,
#  'положил деньги': 1569,
#  'моем': 936,
#  'услуг не': 2319,
#  'ночью': 1165,
#  'звонков смс': 612,
#  'подключенных': 1511,
#  'настоящее': 986,
#  'прав': 1669,
#  'турции': 2276,
#  'отказаться': 1288,
#  'одна': 1219,
#  'исходящие': 697,
#  'специально': 2105,
#  'поменять': 1599,
#  'своей': 1920,
#  'сим карте': 1968,
#  'пальца': 1373,
#  'приходят смс': 1723,
#  'значит': 639,
#  'личный': 818,
#  'обмен': 1183,
#  'находится': 991,
#  'остались': 1269,
#  'тарифном плане': 2218,
#  'остается': 1266,
#  'работают': 1819,
#  'заблокировать номер': 553,
#  '150 рублей': 35,
#  'скорость опуститься': 2001,
#  '155': 38,
#  'денег': 444,
#  'низкая': 1115,
#  'предоставлен': 1679,
#  'моём': 961,
#  'входит': 344,
#  'кому': 766,
#  'менее': 844,
#  'данных true': 422,
#  'отправить сообщение': 1326,
#  'детализация': 469,
#  'узнал интернете': 2295,
#  'данной': 410,
#  'получить детализацию': 1583,
#  'работа': 1808,
#  'не подписывался': 1050,
#  'июнь': 709,
#  'снять': 2070,
#  'заканчивается': 570,
#  'перенести': 1403,
#  'работает интернет': 1810,
#  'отключите услугу': 1301,
#  'плохой': 1481,
#  'вторую': 339,
#  'положительный': 1573,
#  'сумма': 2167,
#  'каким': 726,
#  'отправляла': 1331,
#  'заказа': 561,
#  'списывают': 2131,
#  'туда': 2275,
#  'получилось': 1581,
#  'подключить интернет': 1526,
#  'начала': 998,
#  'такое контент': 2198,
#  'остатки минут': 1276,
#  'россии': 1877,
#  'перевести минуты': 1392,
#  'соц сети': 2100,
#  'назад': 974,
#  'таких': 2194,
#  'интернет стал': 674,
#  'пакета': 1369,
#  'платы': 1472,
#  'не вижу': 1007,
#  'которая': 778,
#  'месяца': 857,
#  'исправить': 695,
#  'платная': 1455,
#  'неудобно': 1110,
#  'подключилась': 1521,
#  'хочу перейти': 2377,
#  'понял': 1616,
#  'написано': 979,
#  'отправить sms': 1324,
#  'звонки теле2': 610,
#  '120': 26,
#  'недели буду': 1086,
#  'тариф': 2200,
#  'верните деньги': 258,
#  'обещанный': 1176,
#  'пополнение': 1621,
#  'начал': 997,
#  'выдает': 351,
#  'минута': 868,
#  'списали деньги': 2108,
#  'соответствии': 2090,
#  'моему': 939,
#  'дело': 443,
#  'хватает': 2363,
#  'абон': 166,
#  'разговоров': 1830,
#  'подключена услуга': 1505,
#  'ко': 754,
#  'плохое': 1480,
#  'бесплатно': 213,
#  'wifi': 154,
#  'номер не': 1143,
#  'не достаточно': 1014,
#  'платные подписки': 1463,
#  'денежные': 445,
#  'компании': 763,
#  'паспорт': 1381,
#  'оплату': 1246,
#  'пропал интернет': 1767,
#  'идут': 647,
#  'вашего': 238,
#  'номер xx': 1140,
#  'ещё не': 540,
#  'безлимитным': 211,
#  'мошенничество': 958,
#  'доступна': 516,
#  'писала': 1432,
#  'еду': 534,
#  'классический': 749,
#  'фамилию': 2354,
#  'периодически': 1427,
#  'область': 1181,
#  'работу': 1821,
#  'гудок': 397,
#  'нигде': 1113,
#  'вынужден': 359,
#  'подскажите': 1542,
#  'доступ интернет': 513,
#  'не отправлял': 1035,
#  'сожалению': 2083,
#  'номером xx': 1158,
#  'услуге': 2326,
#  'убрали': 2277,
#  'заблокирована': 550,
#  'проблема скоростью': 1743,
#  'согласия': 2079,
#  'сегодняшний': 1952,
#  'ваш': 234,
#  'своих': 1925,
#  'службу поддержки': 2016,
#  'уходит': 2349,
#  '611': 114,
#  'автоматически': 186,
#  'тарифе онлайн': 2214,
#  'какие услуги': 725,
#  'абонентов': 171,
#  'тарифного плана': 2216,
#  'новый': 1135,
#  'минут смс': 867,
#  'пополнила счёт': 1629,
#  'оплачивать': 1250,
#  'перешли': 1423,
#  'модель': 922,
#  'заказывала': 569,
#  '04': 6,
#  'лишь': 820,
#  'виджет': 278,
#  'перестала': 1413,
#  'мое': 926,
#  'купить': 806,
#  'сколько стоить': 1991,
#  'использую': 694,
#  'расходуется': 1855,
#  'другого человека': 526,
#  'сказано': 1987,
#  'находиться': 992,
#  'ловить': 825,
#  'мной': 877,
#  'каком': 732,
#  'абонентской платы': 178,
#  'здравствуйте не': 622,
#  'выхода': 366,
#  'хочу': 2375,
#  'теле xx': 2234,
#  'отправлял': 1330,
#  'тарифу онлайн': 2226,
#  'здравствуйте нахожусь': 621,
#  'подключаются': 1498,
#  'оператору': 1239,
#  'заново': 578,
#  'это понимать': 2424,
#  'минут гигабайты': 865,
#  'обычно': 1215,
#  'разговоры': 1831,
#  'произошло списание': 1760,
#  'абсолютно': 183,
#  'вызовов': 356,
#  'звонки': 606,
#  'списывается': 2127,
#  'моему номеру': 940,
#  '11': 24,
#  'рублей сегодня': 1892,
#  'хватило': 2365,
#  'хочу поменять': 2379,
#  'своим номером': 1924,
#  'пишет': 1435,
#  'не мог': 1023,
#  'списана': 2112,
#  'даче': 426,
#  'которому': 783,
#  'рубля': 1895,
#  'не понятно': 1060,
#  'не хватило': 1078,
#  'не удалось': 1074,
#  'прошу пояснить': 1799,
#  'заказ': 560,
#  'sim карту': 140,
#  'моём тарифе': 962,
#  'платную услугу': 1461,
#  'данным': 420,
#  'следующий месяц': 2013,
#  'ст': 2145,
#  'претензию': 1686,
#  'скорость интернета': 1999,
#  'количество': 761,
#  'выше': 368,
#  'персональных данных': 1429,
#  '350р': 89,
#  'настройки': 989,
#  'людей': 829,
#  'переходе': 1418,
#  'меры': 851,
#  'ситуация': 1981,
#  'ввожу номер': 253,
#  'абоненты': 182,
#  'дата': 423,
#  'количества трафика': 760,
#  'переход тариф': 1416,
#  'это ограничение': 2421,
#  ...}

# %%
X_train_tfidf.shape, X_test_tfidf.shape
# Out:
# ((90296, 2438), (10033, 2438))

# %%
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# acc=0.592
ls = LogisticRegression(solver='saga', verbose=1, n_jobs=-1)
ls.fit(X_train_tfidf, y_train_labels)

# acc=
#rf = RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42, verbose=1)
#rf.fit(X_train_tfidf, y_train_labels)
# Out:
# convergence after 18 epochs took 34 seconds
# convergence after 18 epochs took 35 seconds
# convergence after 18 epochs took 35 seconds
# convergence after 19 epochs took 36 seconds
# convergence after 19 epochs took 36 seconds
# convergence after 19 epochs took 36 seconds
# convergence after 20 epochs took 37 seconds
# convergence after 21 epochs took 38 seconds
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:   37.6s remaining:   14.0s
# convergence after 20 epochs took 9 seconds
# convergence after 23 epochs took 10 seconds
# convergence after 23 epochs took 9 seconds
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:   43.9s finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='saga', tol=0.0001,
#           verbose=1, warm_start=False)

# %%
y_hat = ls.predict(X_test_tfidf)
acc_test = np.mean(y_hat==y_test_labels)

print('Accuracy on test data:', acc_test)
# Out:
# Accuracy on test data: 0.6052028306588259

# %%
def show_examples(id_example):
    
    text = data.iloc[id_example]['question']
    predicted_label = le.inverse_transform(y_hat[id_example])
    true_label = le.inverse_transform(y_test_labels[id_example])

    print('True label:', true_label)
    print('Predicted label:', predicted_label)
    print('Text:\n', text)
    print('---')

# %%
for idd in [-1, -5, -42, -2018]:
    show_examples(idd)
# Out:
# True label: прочее
# Predicted label: поступлениеПлатежейОшибочныеПлатежи
# Text:
#  У меня списали средства за обещанный платеж  два раза хотя я его взял один раз
# ---
# True label: тарифыИУслуги
# Predicted label: тарифыИУслуги
# Text:
#  Здравствуйте! Какой у меня тариф?
# ---
# True label: подключенныеУслуги
# Predicted label: подключенныеУслуги
# Text:
#  Здравствуйте! Постоянно!!! Каждый месяц на этот номер подключаете платные услуги. Я команды не ввожу, всплывающие окна заблокированы. Сколько можно? Еще раз такое повториться и уйду от вас. Разберитесь пожалуйста и заблокируйте все платные услуги насовсем.
# ---
# True label: детализацияСчётаИлиЗвонков
# Predicted label: детализацияСчётаИлиЗвонков
# Text:
#  Хочу заказать детализацию звонков,как это сделать?
# ---
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\denis\Anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
