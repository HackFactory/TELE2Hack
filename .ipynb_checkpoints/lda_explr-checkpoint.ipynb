# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Read data

# %%
data = pd.read_json('classic_poems.json', encoding='utf-8')
print(data.shape)
display(data.head())
# Out:
# (2496, 3)
#                                              content  poet_id  \
# 0  Pourquoi craindrais-j'e de ie dire?\nC'est Mar...  pushkin
# 1  Песнь первая\nСвятой монах, грехопадение, юбка...  pushkin
# 2  Внук Тредьяковского Клит гекзаметром песенки п...  pushkin
# 3  Арист! и ты в толпе служителей Парнасса!\nТы х...  pushkin
# 4  (Фингал послал Тоскара воздвигнуть на берегах ...  pushkin
#
#                          title
# 0                    К Наталье
# 1                        Монах
# 2              Несчастие клита
# 3          К другу стихотворцу
# 4  Кольна (Подражание Occèану)

# %% [markdown]
# ### Prepare data

# %%
import re
def clean_txt(s):
    s = re.sub('\n', ' ', s)
    s = re.sub('\d', '', s)
    s = re.sub('[^\w\s]', '', s)
    s = re.sub('\W+', ' ', s)
    s = s.lower()
    return s

data['content'] = data['content'].apply(clean_txt)

# %% [markdown]
# ### Fit tfidf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#from nltk.corpus import stopwords
#import nltk
#nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dvdenis\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
tfidf = TfidfVectorizer(min_df=25, stop_words=stopwords.words('russian'))
X_tfidf = tfidf.fit_transform(data['content'])

# %%
print(X_tfidf.shape)
# Out:
# (2496, 1011)

# %%
tfidf.vocabulary_
# Out:
# {'птица': 677,
#  'сердце': 757,
#  'счастья': 872,
#  'время': 138,
#  'любви': 428,
#  'иль': 346,
#  'любезный': 429,
#  'напрасно': 509,
#  'увы': 938,
#  'ума': 951,
#  'всё': 146,
#  'видел': 102,
#  'тобою': 912,
#  'первый': 597,
#  'целый': 975,
#  'день': 230,
#  'лишь': 415,
#  'ночь': 555,
#  'придет': 658,
#  'вижу': 108,
#  'милая': 457,
#  'мной': 471,
#  'белой': 10,
#  'груди': 205,
#  'снег': 810,
#  'очи': 592,
#  'мрак': 493,
#  'ночи': 553,
#  'дух': 267,
#  'восторг': 132,
#  'нею': 540,
#  'вкруг': 112,
#  'вздох': 97,
#  'глубокой': 167,
#  'сон': 823,
#  'страсть': 854,
#  'любовью': 436,
#  'час': 976,
#  'ум': 950,
#  'чему': 981,
#  'никто': 542,
#  'слух': 793,
#  'скажет': 769,
#  'это': 1005,
#  'вечер': 89,
#  'всюду': 144,
#  'тень': 901,
#  'руку': 716,
#  'взором': 99,
#  'легкой': 400,
#  'рукою': 715,
#  'грудь': 206,
#  'моря': 491,
#  'всей': 139,
#  'надежды': 505,
#  'знаешь': 328,
#  'твой': 889,
#  'нежный': 533,
#  'люблю': 434,
#  'гром': 204,
#  'моей': 478,
#  'руки': 713,
#  'стены': 839,
#  'вечный': 94,
#  'песнь': 602,
#  'святой': 749,
#  'хочу': 968,
#  'певец': 595,
#  'тебе': 893,
#  'ныне': 559,
#  'скажи': 770,
#  'твоя': 891,
#  'ужели': 944,
#  'человек': 980,
#  'коня': 371,
#  'муз': 496,
#  'дай': 212,
#  'твою': 890,
#  'лиру': 410,
#  'буду': 46,
#  'всему': 141,
#  'миру': 468,
#  'поэт': 643,
#  'можешь': 480,
#  'вино': 110,
#  'стану': 836,
#  'петь': 606,
#  'голову': 182,
#  'пусть': 681,
#  'стих': 840,
#  'тех': 903,
#  'златой': 325,
#  'крест': 383,
#  'пустыне': 680,
#  'дикой': 233,
#  'лет': 405,
#  'седой': 751,
#  'дней': 235,
#  'спокойно': 827,
#  'наш': 513,
#  'слишком': 787,
#  'мог': 473,
#  'дом': 243,
#  'жил': 296,
#  'горы': 193,
#  'ваши': 58,
#  'взоры': 100,
#  'хотя': 965,
#  'меж': 446,
#  'двух': 222,
#  'весь': 84,
#  'год': 176,
#  'отец': 586,
#  'коль': 365,
#  'далеко': 214,
#  'наше': 515,
#  'счастлив': 869,
#  'земли': 321,
#  'край': 376,
#  'черный': 985,
#  'дорога': 246,
#  'толпой': 915,
#  'иной': 349,
#  'старый': 838,
#  'одной': 574,
#  'гроб': 200,
#  'молодых': 486,
#  'кровь': 387,
#  'небеса': 523,
#  'шум': 998,
#  'луна': 420,
#  'окно': 579,
#  'пред': 651,
#  'пришел': 662,
#  'черной': 983,
#  'бьет': 54,
#  'хочет': 966,
#  'сидит': 760,
#  'будешь': 45,
#  'собой': 817,
#  'старик': 837,
#  'глаза': 160,
#  'снова': 814,
#  'стал': 830,
#  'тому': 917,
#  'век': 66,
#  'богу': 30,
#  'сил': 761,
#  'слова': 789,
#  'голова': 179,
#  'рука': 709,
#  'упал': 953,
#  'рук': 708,
#  'несчастный': 539,
#  'вперед': 133,
#  'глядит': 169,
#  'вокруг': 122,
#  'свет': 727,
#  'чтото': 989,
#  'углу': 939,
#  'идет': 340,
#  'видит': 105,
#  'покров': 625,
#  'речь': 697,
#  'мое': 476,
#  'любовь': 435,
#  'тонкий': 918,
#  'стан': 834,
#  'ног': 550,
#  'струи': 860,
#  'юный': 1008,
#  'бог': 26,
#  'зеленый': 318,
#  'поздно': 620,
#  'тихонько': 907,
#  'взор': 98,
#  'бьется': 55,
#  'знать': 332,
#  'страсти': 853,
#  'льется': 427,
#  'рад': 689,
#  'мысль': 500,
#  'скоро': 777,
#  'покоя': 624,
#  'спит': 826,
#  'беда': 5,
#  'моем': 479,
#  'ко': 362,
#  'прости': 667,
#  'сказать': 773,
#  'делать': 227,
#  'знал': 331,
#  'искал': 351,
#  'остался': 584,
#  'проходит': 670,
#  'везде': 65,
#  'свечи': 736,
#  'спать': 825,
#  'лучи': 425,
#  'небес': 522,
#  'хотел': 964,
#  'смотреть': 804,
#  'моего': 477,
#  'вновь': 116,
#  'чудный': 992,
#  'средь': 829,
#  'стоит': 845,
#  'кубок': 395,
#  'черных': 986,
#  'легкий': 398,
#  'говорит': 173,
#  'поет': 618,
#  'сердца': 756,
#  'толпы': 916,
#  'детей': 231,
#  'дев': 223,
#  'тени': 900,
#  'ложе': 416,
#  'роз': 700,
#  'рот': 706,
#  'душе': 269,
#  'лес': 403,
#  'конь': 370,
#  'новой': 545,
#  'кольцо': 366,
#  'изза': 344,
#  'лицо': 413,
#  'исчез': 352,
#  'вид': 101,
#  'глухой': 168,
#  'ах': 2,
#  'небесах': 524,
#  'горя': 194,
#  'восток': 131,
#  'заря': 310,
#  'встал': 143,
#  'думал': 265,
#  'тобой': 911,
#  'ночью': 556,
#  'сном': 815,
#  'снится': 812,
#  'смотрел': 803,
#  'радости': 690,
#  'свой': 748,
#  'кем': 360,
#  'своим': 746,
#  'всем': 140,
#  'милые': 459,
#  'сне': 809,
#  'ждать': 280,
#  'последний': 639,
#  'очень': 591,
#  'рок': 702,
#  'водой': 119,
#  'готов': 198,
#  'ждет': 281,
#  'своей': 743,
#  'пыли': 685,
#  'луны': 421,
#  'природа': 660,
#  'народа': 511,
#  'стихи': 842,
#  'головою': 181,
#  'волос': 128,
#  'головы': 183,
#  'венок': 70,
#  'милых': 461,
#  'волной': 126,
#  'реки': 695,
#  'нем': 535,
#  'навеки': 502,
#  'песни': 601,
#  'враг': 135,
#  'землю': 322,
#  'туман': 930,
#  'сквозь': 774,
#  'жив': 287,
#  'руками': 710,
#  'брег': 42,
#  'глазах': 162,
#  'пламень': 613,
#  'сей': 752,
#  'призрак': 659,
#  'добрый': 239,
#  'передо': 598,
#  'мною': 472,
#  'будь': 48,
#  'друг': 253,
#  'твои': 886,
#  'забыл': 302,
#  'народ': 510,
#  'жить': 297,
#  'слов': 788,
#  'моих': 483,
#  'руках': 711,
#  'смотри': 805,
#  'злой': 326,
#  'оставь': 583,
#  'моим': 482,
#  'ищет': 353,
#  'дружбы': 261,
#  'свои': 745,
#  'ноги': 551,
#  'дороги': 248,
#  'стихов': 843,
#  'жар': 278,
#  'хочешь': 967,
#  'смело': 798,
#  'бой': 32,
#  'забудь': 300,
#  'леса': 404,
#  'могилы': 474,
#  'вниз': 115,
#  'довольно': 240,
#  'навек': 501,
#  'сенью': 755,
#  'гений': 156,
#  'жребий': 298,
#  'пал': 593,
#  'обо': 563,
#  'легко': 399,
#  'честь': 988,
#  'слава': 778,
#  'вместе': 114,
#  'едва': 276,
#  'станет': 835,
#  'печать': 610,
#  'судьбой': 864,
#  'землей': 320,
#  'мимо': 462,
#  'жизнь': 294,
#  'ряд': 720,
#  'кажется': 355,
#  'немного': 536,
#  'новый': 547,
#  'сюда': 874,
#  'стихами': 841,
#  'ответ': 585,
#  'шел': 995,
#  'навстречу': 504,
#  'пить': 612,
#  'сегодня': 750,
#  'сказал': 772,
#  'тихой': 906,
#  'любит': 432,
#  'руке': 712,
#  'полно': 629,
#  'дал': 213,
#  'совет': 819,
#  'некогда': 534,
#  'дочь': 251,
#  'чувства': 991,
#  'волны': 127,
#  'звезд': 311,
#  'темный': 897,
#  'небу': 528,
#  'другу': 260,
#  'царь': 971,
#  'стало': 833,
#  'путь': 683,
#  'мгле': 444,
#  'вечерний': 91,
#  'утро': 956,
#  'темные': 896,
#  'бежит': 7,
#  'гор': 188,
#  'рукой': 714,
#  'волн': 124,
#  'кровью': 388,
#  'меч': 451,
#  'щит': 1000,
#  'сын': 873,
#  'страшный': 858,
#  'дорогой': 249,
#  'снов': 813,
#  'солнца': 820,
#  'герой': 157,
#  'времен': 136,
#  'темных': 898,
#  'берег': 15,
#  'молодой': 485,
#  'золотой': 337,
#  'тяжко': 935,
#  'блеск': 20,
#  'крови': 386,
#  'сна': 808,
#  'сени': 754,
#  'темной': 895,
#  'рощи': 707,
#  'месяц': 449,
#  'сияет': 768,
#  'ужель': 945,
#  'стране': 850,
#  'тишина': 909,
#  'нежной': 532,
#  'младой': 469,
#  'силах': 763,
#  'новым': 548,
#  'ль': 426,
#  'вдали': 60,
#  'шумит': 999,
#  'волна': 125,
#  'тихий': 904,
#  'глас': 163,
#  'тьме': 934,
#  'ночной': 554,
#  'одна': 570,
#  'села': 753,
#  'летит': 407,
#  'сладко': 781,
#  'душа': 268,
#  'душою': 272,
#  'дремлет': 252,
#  'заре': 308,
#  'мои': 481,
#  'лежит': 401,
#  'идут': 342,
#  'прочь': 671,
#  'печаль': 608,
#  'близ': 23,
#  'страстью': 855,
#  'огонь': 569,
#  'твоей': 884,
#  'снега': 811,
#  'друга': 254,
#  'кровавый': 385,
#  'смерти': 799,
#  'дали': 215,
#  'море': 490,
#  'веселье': 79,
#  'прах': 650,
#  'главой': 158,
#  'теней': 899,
#  'улыбкой': 949,
#  'луч': 422,
#  'рано': 693,
#  'любил': 430,
#  'казалось': 356,
#  'быстро': 53,
#  'дни': 237,
#  'порой': 637,
#  'дверь': 221,
#  'шепчет': 996,
#  'милый': 460,
#  'тихо': 905,
#  'мгла': 443,
#  'тумане': 931,
#  'грозный': 203,
#  'бледный': 19,
#  'молчанье': 488,
#  'тоской': 921,
#  'мире': 466,
#  'души': 270,
#  'родной': 698,
#  'имя': 348,
#  'сумрак': 867,
#  'друзей': 262,
#  'среди': 828,
#  'пыл': 684,
#  'весть': 83,
#  'смерть': 801,
#  'кругом': 390,
#  'мир': 464,
#  'осень': 582,
#  'порою': 638,
#  'вершины': 74,
#  'говорил': 172,
#  'сердцу': 759,
#  'огнем': 566,
#  'счастливый': 870,
#  'тенью': 902,
#  'улыбка': 948,
#  'мраке': 494,
#  'весны': 82,
#  'мечты': 455,
#  'душой': 271,
#  'мечтой': 453,
#  'поля': 632,
#  'веет': 64,
#  'поток': 640,
#  'даль': 216,
#  'разлуки': 692,
#  'собою': 818,
#  'знакомый': 330,
#  'мира': 465,
#  'пор': 635,
#  'гляжу': 171,
#  'дня': 238,
#  'оно': 581,
#  'слез': 784,
#  'смотрю': 807,
#  'прежде': 654,
#  'пускай': 679,
#  'окна': 577,
#  'дым': 274,
#  'гонит': 187,
#  'которой': 374,
#  'вся': 145,
#  'места': 447,
#  'печали': 607,
#  'мечта': 452,
#  'судьба': 862,
#  'нам': 507,
#  'слезы': 786,
#  'право': 648,
#  'верный': 73,
#  'две': 219,
#  'окном': 580,
#  'страшно': 857,
#  'воды': 120,
#  'радость': 691,
#  'страх': 856,
#  'высоко': 148,
#  'след': 783,
#  'славой': 779,
#  'вслед': 142,
#  'крылья': 393,
#  'счастье': 871,
#  'видно': 107,
#  'богом': 29,
#  'жизни': 293,
#  'закон': 306,
#  'ужасный': 943,
#  'траве': 924,
#  'светлый': 734,
#  'бродит': 44,
#  'простой': 669,
#  'пел': 596,
#  'гул': 210,
#  'глубины': 165,
#  'вином': 111,
#  'головой': 180,
#  'глаз': 159,
#  'вечной': 93,
#  'тишине': 910,
#  'медленно': 445,
#  'белый': 13,
#  'милой': 458,
#  'звук': 316,
#  'лицом': 414,
#  'сердцем': 758,
#  'блещет': 22,
#  'стон': 846,
#  'горе': 189,
#  'вина': 109,
#  'муки': 498,
#  'могу': 475,
#  'вечно': 92,
#  'миг': 456,
#  'красоты': 379,
#  'времени': 137,
#  'смертный': 800,
#  'той': 914,
#  'свод': 740,
#  'небесный': 526,
#  'холод': 961,
#  'поле': 626,
#  'дома': 244,
#  'друзья': 263,
#  'брат': 41,
#  'сонный': 824,
#  'круг': 389,
#  'твоих': 888,
#  'нашей': 516,
#  'музы': 497,
#  'товарищ': 913,
#  'который': 375,
#  'одним': 572,
#  'любимый': 431,
#  'смеется': 797,
#  'часто': 977,
#  'страны': 851,
#  'вчера': 147,
#  'словом': 792,
#  'пою': 645,
#  'муж': 495,
#  'сколько': 775,
#  'венец': 69,
#  'царя': 972,
#  'бывало': 52,
#  'своих': 747,
#  'люди': 439,
#  'отца': 588,
#  'язык': 1009,
#  'долго': 242,
#  'крепко': 382,
#  'двери': 220,
#  'речи': 696,
#  'завтра': 303,
#  'други': 256,
#  'домой': 245,
#  'верно': 72,
#  'молодая': 484,
#  'ангел': 1,
#  'сама': 724,
#  'стала': 831,
#  'боже': 31,
#  'прекрасной': 656,
#  'света': 728,
#  'весело': 77,
#  'людей': 438,
#  'бедный': 6,
#  'больно': 36,
#  'место': 448,
#  'скажу': 771,
#  'такое': 882,
#  'прав': 647,
#  'жены': 286,
#  'душу': 273,
#  'нежно': 531,
#  'днем': 236,
#  'слышен': 795,
#  'пой': 621,
#  'свете': 729,
#  'вышине': 153,
#  'слезами': 785,
#  'боле': 33,
#  'гости': 196,
#  'веселый': 78,
#  'воле': 123,
#  'славы': 780,
#  'удел': 941,
#  'ужас': 942,
#  'любить': 433,
#  'прежних': 655,
#  'плывет': 617,
#  'очами': 589,
#  'луг': 418,
#  'вод': 117,
#  'полей': 627,
#  'храм': 969,
#  'сад': 722,
#  'россии': 704,
#  'те': 892,
#  'россия': 705,
#  'каждый': 354,
#  'шаг': 994,
#  'лета': 406,
#  'пройдет': 665,
#  'новые': 546,
#  'ними': 543,
#  'земля': 323,
#  'небо': 527,
#  'летят': 408,
#  'близок': 25,
#  'строй': 859,
#  'пир': 611,
#  'гремит': 199,
#  'русской': 718,
#  'края': 381,
#  'родные': 699,
#  'часы': 978,
#  'золотые': 338,
#  'одни': 571,
#  'унылый': 952,
#  'туда': 929,
#  'молчит': 489,
#  'мать': 442,
#  'бегут': 4,
#  'утром': 957,
#  'несет': 538,
#  'земле': 319,
#  'наших': 518,
#  'горит': 190,
#  'дар': 218,
#  'небесной': 525,
#  'дева': 224,
#  'тайный': 879,
#  'дитя': 234,
#  'матери': 441,
#  'чужой': 993,
#  'других': 259,
#  'конца': 369,
#  'предел': 652,
#  'пока': 622,
#  'берега': 16,
#  'невольно': 529,
#  'изпод': 345,
#  'полна': 628,
#  'воздух': 121,
#  'сладкой': 782,
#  'украдкой': 947,
#  'богов': 28,
#  'розы': 701,
#  'девы': 225,
#  'et': 0,
#  'весной': 81,
#  'образ': 564,
#  'весна': 80,
#  'бури': 49,
#  'дети': 232,
#  'пора': 636,
#  'говорю': 174,
#  'цвет': 973,
#  'лица': 412,
#  'таков': 881,
#  'утра': 955,
#  'года': 177,
#  'дела': 226,
#  'дорогу': 250,
#  'живу': 290,
#  'живет': 288,
#  'ходит': 960,
#  'забот': 299,
#  'живут': 291,
#  'стали': 832,
#  'любя': 437,
#  'видеть': 104,
#  'ими': 347,
#  'свист': 737,
#  'забыв': 301,
#  'зари': 309,
#  'тиши': 908,
#  'голос': 184,
#  'неба': 520,
#  'светом': 735,
#  'предо': 653,
#  'юности': 1006,
#  'очей': 590,
#  'тоскою': 922,
#  'кого': 364,
#  'жена': 284,
#  'свое': 741,
#  'зовет': 335,
#  'ту': 928,
#  'впереди': 134,
#  'слово': 791,
#  'плачет': 615,
#  'конец': 368,
#  'взгляд': 95,
#  'кому': 367,
#  'знаю': 334,
#  'равно': 688,
#  'раб': 687,
#  'кипит': 361,
#  'свобода': 738,
#  'берегу': 18,
#  'народы': 512,
#  'светлой': 733,
#  'мало': 440,
#  'своем': 744,
#  'тучи': 933,
#  'думы': 266,
#  'угрюмый': 940,
#  'черные': 984,
#  'давно': 211,
#  'свободы': 739,
#  'крылом': 392,
#  'звезда': 312,
#  'гроза': 202,
#  'гость': 197,
#  'желанья': 283,
#  'видишь': 106,
#  'звон': 315,
#  'гроба': 201,
#  'оба': 561,
#  'полный': 630,
#  'ветер': 85,
#  'лик': 409,
#  'просит': 666,
#  'лени': 402,
#  'издали': 343,
#  'волшебный': 129,
#  'саду': 723,
#  'наши': 517,
#  'звезды': 313,
#  'лучей': 424,
#  'поэта': 644,
#  'мою': 492,
#  'будут': 47,
#  'память': 594,
#  'праздник': 649,
#  'ваш': 57,
#  'стоят': 848,
#  'нами': 508,
#  'холодный': 963,
#  'дело': 229,
#  'пламя': 614,
#  'покой': 623,
#  'минуты': 463,
#  'вечерней': 90,
#  'судьбе': 863,
#  'ведет': 63,
#  'деле': 228,
#  'поют': 646,
#  'город': 191,
#  'полон': 631,
#  'река': 694,
#  'облака': 562,
#  'золотая': 336,
#  'камень': 359,
#  'смотрит': 806,
#  'наша': 514,
#  'младость': 470,
#  'высоты': 149,
#  'роковой': 703,
#  'таинственный': 876,
#  'власть': 113,
#  'нашу': 519,
#  'миром': 467,
#  'молча': 487,
#  'когдато': 363,
#  'прошли': 673,
#  'знает': 327,
#  'ложь': 417,
#  'ваших': 59,
#  'ночам': 552,
#  'труд': 925,
#  'дум': 264,
#  'труда': 926,
#  'вами': 56,
#  'земной': 324,
#  'другие': 257,
#  'нему': 537,
#  'твоим': 887,
#  'прямо': 676,
#  'точно': 923,
#  'значит': 333,
#  'прошла': 672,
#  'прошло': 674,
#  'узнал': 946,
#  'сила': 762,
#  'тайной': 878,
#  'своего': 742,
#  'жизнью': 295,
#  'бога': 27,
#  'одну': 575,
#  'чаще': 979,
#  'живой': 289,
#  'цветы': 974,
#  'вдохновенья': 62,
#  'белом': 11,
#  'слышу': 796,
#  'огни': 567,
#  'жду': 282,
#  'глубине': 164,
#  'мечту': 454,
#  'пути': 682,
#  'судьбы': 865,
#  'черты': 987,
#  'тайно': 877,
#  'века': 67,
#  'силой': 764,
#  'кудри': 396,
#  'твое': 883,
#  'крик': 384,
#  'светло': 732,
#  'больной': 37,
#  'ясно': 1010,
#  'глубоко': 166,
#  'далёко': 217,
#  'какойто': 358,
#  'ждал': 279,
#  'небе': 521,
#  'одно': 573,
#  'смех': 802,
#  'тянет': 936,
#  'силы': 765,
#  'огня': 568,
#  'берегов': 17,
#  'лист': 411,
#  'ветра': 87,
#  'тоски': 920,
#  'бездной': 8,
#  'помню': 634,
#  'глазами': 161,
#  'ктото': 394,
#  'увидел': 937,
#  'полях': 633,
#  'горят': 195,
#  'печальный': 609,
#  'дышит': 275,
#  'страданья': 849,
#  'назад': 506,
#  'песен': 599,
#  'уста': 954,
#  'другим': 258,
#  'навсегда': 503,
#  'жаль': 277,
#  'звуки': 317,
#  'страстей': 852,
#  'вода': 118,
#  'веры': 75,
#  'нужен': 557,
#  'вон': 130,
#  'юность': 1007,
#  'грусть': 208,
#  'прощай': 675,
#  'никому': 541,
#  'ушла': 959,
#  'природы': 661,
#  'холодной': 962,
#  'песней': 600,
#  'пошел': 641,
#  'города': 192,
#  'нужно': 558,
#  'иду': 341,
#  'пришли': 664,
#  'годы': 178,
#  'скорей': 776,
#  'красный': 378,
#  'огне': 565,
#  'луга': 419,
#  'христа': 970,
#  'выше': 151,
#  'бурь': 50,
#  'твоем': 885,
#  'пошли': 642,
#  'пришла': 663,
#  'виденья': 103,
#  'эй': 1001,
#  'откуда': 587,
#  'чувств': 990,
#  'самом': 725,
#  'живые': 292,
#  'слушать': 794,
#  'сны': 816,
#  'сто': 844,
#  'привет': 657,
#  'просто': 668,
#  'самый': 726,
#  'верю': 76,
#  'верить': 71,
#  'новых': 549,
#  'тело': 894,
#  'суровый': 868,
#  'суд': 861,
#  'этих': 1004,
#  'другая': 255,
#  'блестит': 21,
#  'красные': 377,
#  'заката': 305,
#  'какие': 357,
#  'нынче': 560,
#  'пыль': 686,
#  'светла': 731,
#  'краю': 380,
#  'большой': 38,
#  'говорят': 175,
#  'труп': 927,
#  'великий': 68,
#  'солнце': 821,
#  'буря': 51,
#  'ветр': 86,
#  'дождь': 241,
#  'вдоль': 61,
#  'бег': 3,
#  'черная': 982,
#  'грустно': 207,
#  'иные': 350,
#  'белая': 9,
#  'взглядом': 96,
#  'птицы': 678,
#  'этим': 1003,
#  'мысли': 499,
#  'вышел': 152,
#  'женщин': 285,
#  'та': 875,
#  'светит': 730,
#  'ветром': 88,
#  'бою': 40,
#  'шли': 997,
#  'эта': 1002,
#  'недаром': 530,
#  'стою': 847,
#  'звенит': 314,
#  'песня': 604,
#  'солнцем': 822,
#  'песню': 603,
#  'лазури': 397,
#  'знак': 329,
#  'тоска': 919,
#  'ой': 576,
#  'белых': 14,
#  'такая': 880,
#  'туманы': 932,
#  'дороге': 247,
#  'синий': 766,
#  'метель': 450,
#  'ушел': 958,
#  'нити': 544,
#  'песок': 605,
#  'лучах': 423,
#  'рядом': 721,
#  'вьюга': 154,
#  'сумерки': 866,
#  'губы': 209,
#  'пожар': 619,
#  'глядят': 170,
#  'закат': 304,
#  'русский': 717,
#  'белые': 12,
#  'русь': 719,
#  'запах': 307,
#  'словно': 790,
#  'крыла': 391,
#  'плечи': 616,
#  'близко': 24,
#  'боли': 34,
#  'костер': 373,
#  ...}

# %% [markdown]
# ### LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA = LatentDirichletAllocation(n_components=50, max_iter=25, n_jobs=-1, verbose=1, random_state=42)
LDA.fit(X_tfidf)
# Out:
# C:\Users\dvdenis\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 25
# iteration: 2 of max_iter: 25
# iteration: 3 of max_iter: 25
# iteration: 4 of max_iter: 25
# iteration: 5 of max_iter: 25
# iteration: 6 of max_iter: 25
# iteration: 7 of max_iter: 25
# iteration: 8 of max_iter: 25
# iteration: 9 of max_iter: 25
# iteration: 10 of max_iter: 25
# iteration: 11 of max_iter: 25
# iteration: 12 of max_iter: 25
# iteration: 13 of max_iter: 25
# iteration: 14 of max_iter: 25
# iteration: 15 of max_iter: 25
# iteration: 16 of max_iter: 25
# iteration: 17 of max_iter: 25
# iteration: 18 of max_iter: 25
# iteration: 19 of max_iter: 25
# iteration: 20 of max_iter: 25
# iteration: 21 of max_iter: 25
# iteration: 22 of max_iter: 25
# iteration: 23 of max_iter: 25
# iteration: 24 of max_iter: 25
# iteration: 25 of max_iter: 25
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7, learning_method=None,
#              learning_offset=10.0, max_doc_update_iter=100, max_iter=25,
#              mean_change_tol=0.001, n_components=50, n_jobs=-1,
#              n_topics=None, perp_tol=0.1, random_state=42,
#              topic_word_prior=None, total_samples=1000000.0, verbose=1)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(LDA, list(tfidf.vocabulary_.keys()), no_top_words)
# Out:
# Topic 0:
# луна дом живет пал знает память нею двух сияет ваш
#
# Topic 1:
# крылья стих навстречу солнца волос какие видеть рок глядит ответ
#
# Topic 2:
# тебе миром конец другая полна моря сила роковой ними глубоко
#
# Topic 3:
# ушла сумерки головой гонит некогда водой память сумрак пускай боже
#
# Topic 4:
# красоты молодой кем бой полей страх близок конец душу это
#
# Topic 5:
# воды праздник ужели бог поздно часы откуда жаль век дум
#
# Topic 6:
# грозный несет казалось розы мгле удел ложь луч искал вода
#
# Topic 7:
# кудри тенью небесной душу пора тени всей честь дружбы кипит
#
# Topic 8:
# свете лик мимо мою глядят певец кем друга милая покров
#
# Topic 9:
# смотрит город дух всем дорогу той полно друзей молодых несчастный
#
# Topic 10:
# мир нему новой других бездной видишь веселый ищет деле русь
#
# Topic 11:
# юности любил иль след ушла хочу отец счастлив веет рано
#
# Topic 12:
# меж светла судьбы свои сумерки даль пока сказал груди стих
#
# Topic 13:
# сумрак рано счастлив небо вод других стан добрый лиру жил
#
# Topic 14:
# тоска всюду след душою никому богу пошел ваш прошло глаза
#
# Topic 15:
# наша остался будут лицо глас темные знал новых юный узнал
#
# Topic 16:
# глубокой покоя ответ дела глубине вьюга высоты сердцу небу пить
#
# Topic 17:
# вышел чувств земля седой славы руке корабли полный времени моим
#
# Topic 18:
# холодной след человек пламя море слух солнце слишком тайный боже
#
# Topic 19:
# венец всему твоих глубоко вперед любовью глубокой дух добрый жаль
#
# Topic 20:
# боже рано тайный моих дышит тенью память славой лежит заря
#
# Topic 21:
# пор мечту блестит веет сюда станет горят назад миру море
#
# Topic 22:
# слышен ужасный стоят море девы силах вьюга ль молчит луч
#
# Topic 23:
# рано стою хочу ваш зеленый тихой видно свете ночь лицом
#
# Topic 24:
# плывет вокруг иные близко скажу волна слезами вдоль суровый юный
#
# Topic 25:
# юности других пришел словно луга моих новый огни месяц значит
#
# Topic 26:
# очень счастья кудри сто глас герой сколько море холодной прошли
#
# Topic 27:
# крови других лицо тихий небесах любимый чудный луч старик ряд
#
# Topic 28:
# пламя меж стон полно окна чувств своем кем простой свод
#
# Topic 29:
# полный собою часто миром навеки смерть часы завтра счастлив долго
#
# Topic 30:
# ужас дочь любезный кольцо звезды мои стихи бог гроба берег
#
# Topic 31:
# птица музы любить река душа снится горят небес тянет лицо
#
# Topic 32:
# полно землей готов ужели думы синь крест силой закат богу
#
# Topic 33:
# разлуки синий вечерней тумане сердцем бьется близок смерть совет сна
#
# Topic 34:
# судьбы звезд царя гроба шепчет милых лучей бедный высоты стану
#
# Topic 35:
# счастья вон смерти прощай света воздух мраке снов веет птицы
#
# Topic 36:
# сад лицо пыль весь ноги песок пошел et богу мрак
#
# Topic 37:
# голос сил дева порой дня близок холодной пускай пошел веет
#
# Topic 38:
# волос звенит пой предо богу смерть давно власть весь далеко
#
# Topic 39:
# сказал сенью камень милые юный ктото ум зовет сюда узнал
#
# Topic 40:
# богу ушла ветер ах пошел окном лежит холод боль руках
#
# Topic 41:
# деле страданья розы мысль язык тенью моих просит последний нею
#
# Topic 42:
# мрак сердца вкруг можешь блещет чаще счастья любовь улыбкой даль
#
# Topic 43:
# дорога черный пой весь молодой мало страшно твоим слезами ночной
#
# Topic 44:
# лазури летят седой спит язык печальный блестит прочь вкруг покоя
#
# Topic 45:
# власть века лени ваши свой волос труда свод сени веры
#
# Topic 46:
# бури вон конь солнце ноги звенит слух старик лежит твоем
#
# Topic 47:
# ангел выше водой хочет иной стала ночной огне судьба другу
#
# Topic 48:
# снег наш тишина назад плачет ложь стены русской славы порою
#
# Topic 49:
# толпы глубокой последний людей звезд свое христа вечерней рукой лет
