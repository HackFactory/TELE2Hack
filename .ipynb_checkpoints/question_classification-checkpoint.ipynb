# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import stopwords
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import eli5
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read data

# %%
data = pd.read_csv('D:/tele2_data_hack/email_reports.csv')
print(data.shape)
# Out:
# (125938, 10)

# %%
data.head()
# Out:
#      SENDER_ID    SENDER_EMAIL OPERATOR_ID                   ACCEPTOR  \
# 0   token_7747  xxxx@yandex.ru    token_48        spb.vopros@tele2.ru
# 1  token_14226    xxxx@mail.ru    token_50    Saransk.Vopros@tele2.ru
# 2  token_23942    xxxx@mail.ru     token_3     rostov.vopros@tele2.ru
# 3  token_18368    xxxx@mail.ru    token_53  krasnodar.vopros@tele2.ru
# 4  token_21039    xxxx@mail.ru    token_34   kostroma.vopros@tele2.ru
#
#                  SUBJECT        To.queue.time   agent.receive.time  \
# 0         Обратная связь  2088-06-17 02:31:32  2088-06-18 19:48:26
# 1  Re[2]: Обратная связь  2088-06-17 02:31:52  2088-06-18 18:43:45
# 2         Обратная связь  2088-06-17 02:33:14  2088-06-18 18:43:45
# 3         Обратная связь  2088-06-17 02:33:36  2088-06-18 19:49:10
# 4         Обратная связь  2088-06-17 02:33:56  2088-06-18 19:49:17
#
#     treatment.end.time                                            CONTENT  \
# 0  2088-06-18 20:24:59  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 1  2088-06-18 18:58:43    \r\nвся необходимая информация отображена в ...
# 2  2088-06-18 18:47:06  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 3  2088-06-18 19:53:57  Тело письма\r\n\r\nMSISDN: +xxx xxx xx xx\r\nО...
# 4  2088-06-18 19:59:48  Тело письма\r\n\r\nОтметьте, в каком регионе В...
#
#                                           ANSWERTEXT
# 0  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx!\r\n\r...
# 1  Здравствуйте, xxxxx xxxxx xxxxx!\r\nБлагодарим...
# 2  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx!\r\nБл...
# 3  \r\n\r\nЗдравствуйте, xxxxx xxxxx xxxxx! ¦\r\n...
# 4  \r\n\r\nАлександр, доброго времени суток! ;)\r...

# %% [markdown]
# # determine fraction of each problem

# %%
# for training classifier use only letters for support 
print(data.shape)
data = data[data['CONTENT'].apply(lambda x: 'Тело письма' in str(x))].reset_index(drop=True)
print(data.shape)
# Out:
# (125938, 10)
# (102898, 10)

# %% [markdown]
# ### Get question from user and topic of this question

# %%
def get_topic(x):
    ret = ''
    try:
        ret = x.split('Выберите тему обращения: ')[1].split('\r')[0]
    except:
        pass
    return ret

def get_question(x):
    ret = ''
    try:
        ret = x.split('Выберите тему обращения: ')[1].split('\r')[1].split('\nЗадайте ваш вопрос или опишите проблему: ')[1]
    except:
        pass
    return ret


data['topic'] = data['CONTENT'].apply(lambda x: get_topic(x))
data['question'] = data['CONTENT'].apply(lambda x: get_question(x))

# %% [markdown]
# ### Statistics of topics

# %%
temp = data[['topic','CONTENT']].groupby('topic').agg('count').reset_index()
temp = temp.rename_axis({'CONTENT':'Number of questions'},axis=1)
num_q = np.sum(temp['Number of questions'])
temp = temp[temp['Number of questions']>1200].reset_index(drop=True)

temp['Topic fraction'] = temp['Number of questions'] / num_q * 100
print('Most popular topics fraction: ', np.sum(temp['Topic fraction']), '%')
# Out:
# Most popular topics fraction:  97.50335283484615 %

# %%
temp.sort_values(by='Topic fraction', ascending=False)
# Out:
#                                   topic  Number of questions  Topic fraction
# 8                                прочее                24434       23.745845
# 10                        тарифыИУслуги                18770       18.241365
# 3                     мобильныйИнтернет                15918       15.469688
# 6                    подключенныеУслуги                 9112        8.855371
# 2                         личныйКабинет                 7379        7.171179
# 9              роумингИЗонаОбслуживания                 6732        6.542401
# 7   поступлениеПлатежейОшибочныеПлатежи                 6045        5.874750
# 1            детализацияСчётаИлиЗвонков                 5474        5.319831
# 0      блокировкаИРазблокировкаSimКарты                 2412        2.344069
# 5                     подключениеКTele2                 2398        2.330463
# 4                   переносНомераВTele2                 1655        1.608389

# %%
most_freq_topics = list(temp['topic'])

# %%
# keep only freq topics 
data = data[data['topic'].apply(lambda x: x in most_freq_topics)].reset_index(drop=True)

# %% [markdown]
# ### Prepare data for test classification

# %%
X_train, X_test, y_train, y_test = train_test_split(data['question'], data['topic'], 
                                                    shuffle=False, 
                                                    test_size=0.1)

# %%
le = LabelEncoder()
y_train_labels = le.fit_transform(y_train)
y_test_labels = le.transform(y_test)

# %%
xs_seq = []
for n_x in np.arange(10,2,-1):
    xs_seq.append('x'*n_x)
    
def preprocess_string(x):
    for xs in xs_seq:
        x = re.sub(xs, ' ', x)
    return x

X_train = X_train.apply(lambda x: preprocess_string(x))
X_test = X_test.apply(lambda x: preprocess_string(x))

# %%
stopWords = set(stopwords.words('russian'))
stopWords = list(stopWords)
stopWords = stopWords + ['вечер', 'добрый', 'день', 'скажите', 'пожалуйста', 'спасибо', 'ли', 'почему', 'вопрос']
stopWords.remove('не')
stopWords = set(stopWords)
print('Number of stop words:', len(stopWords))
# Out:
# Number of stop words: 158

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 2), min_df=100, max_df=0.99, stop_words=stopWords)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
tfidf.vocabulary_
# Out:
# {'дней остается': 473,
#  'сами': 1906,
#  'платных услуг': 1469,
#  'положил деньги': 1569,
#  'тариф теле2': 2209,
#  'утро': 2347,
#  'такое': 2197,
#  'не подключается': 1044,
#  'онлайн': 1229,
#  'переносе': 1408,
#  'списалась': 2106,
#  'моего ведома': 928,
#  'фз': 2357,
#  'правильно': 1670,
#  'являюсь абонентом': 2433,
#  'отключить платную': 1306,
#  'звоню': 614,
#  'одном': 1224,
#  'ловит интернет': 823,
#  'интересует': 664,
#  'позже узнал': 1553,
#  'этому': 2429,
#  'привет': 1687,
#  'проблема не': 1742,
#  'сменить оператора': 2031,
#  'личный кабинет': 819,
#  'разрешения': 1838,
#  '200 рублей': 51,
#  'звонки теле2': 610,
#  'общаться': 1211,
#  'услуги не': 2330,
#  'каждый': 720,
#  'очень плохой': 1351,
#  'подключил услугу': 1517,
#  '14': 28,
#  'вместе': 288,
#  'возврата': 301,
#  'приходит сообщение': 1719,
#  'ндс отключения': 1004,
#  'нужна': 1168,
#  'обычно': 1215,
#  'возможных нагрузках': 308,
#  'качество связи': 747,
#  'отключены': 1296,
#  'интернет вообще': 666,
#  'никуда': 1128,
#  'связи интернета': 1935,
#  '18': 41,
#  'перестала': 1413,
#  'подключил тариф': 1516,
#  'убрать': 2278,
#  'не правильно': 1062,
#  '30гб': 82,
#  'неделю': 1088,
#  'московской': 956,
#  'тариф беспредельно': 2201,
#  'хочу отключить': 2376,
#  '04': 6,
#  'супер': 2171,
#  'не помогает': 1058,
#  'сегодняшний': 1952,
#  'сервис': 1953,
#  'передача данных': 1395,
#  'никакого': 1123,
#  'причине': 1727,
#  'работы': 1822,
#  'указанный': 2299,
#  'моего счёта': 932,
#  'сделать не': 1950,
#  'puk код': 137,
#  'ко': 754,
#  'достаточно средств': 511,
#  'дважды': 427,
#  'постоянные': 1650,
#  'фото': 2359,
#  'могу поменять': 914,
#  '900': 120,
#  'могу звонить': 903,
#  'моего согласия': 930,
#  'ммс': 876,
#  'смс кодом': 2042,
#  '180': 42,
#  'хочу узнать': 2380,
#  '199': 45,
#  'сайт': 1898,
#  'могу сделать': 918,
#  'попытке': 1636,
#  'очень': 1347,
#  'запрос': 583,
#  'отключила': 1298,
#  'снимают деньги': 2058,
#  'поступили': 1653,
#  '3g': 91,
#  'свой тариф': 1929,
#  'отправляются': 1333,
#  'хотела узнать': 2369,
#  'имелось': 657,
#  'каком основании': 733,
#  'тв': 2228,
#  'отключите услугу': 1301,
#  '100р': 22,
#  'сим карты': 1971,
#  'мое': 926,
#  'списывается': 2127,
#  'удалить': 2289,
#  'ответа': 1282,
#  'платная услуга': 1457,
#  'собираюсь': 2072,
#  '60': 111,
#  'отпечатку пальца': 1319,
#  'здравствуйте хочу': 636,
#  'вашей компании': 241,
#  'подключенных': 1511,
#  'услугу': 2332,
#  'мошенничество': 958,
#  'сказали': 1986,
#  'хотелось узнать': 2371,
#  'исчезли': 700,
#  'не получил': 1053,
#  'невозможно': 1082,
#  'подскажите могу': 1543,
#  'минуты': 870,
#  'sms': 141,
#  'вопросы': 320,
#  '35': 85,
#  'обещанный платеж': 1177,
#  'уважаемые': 2279,
#  'ведома согласия': 255,
#  'плохо работает': 1479,
#  'приложением': 1697,
#  'счёта': 2183,
#  'детализация звонков': 470,
#  'свое': 1917,
#  'решите проблему': 1873,
#  'перейду': 1398,
#  'услуга подключена': 2323,
#  'старую': 2152,
#  'знаю': 641,
#  'постоянно': 1648,
#  'скоростью интернета': 2006,
#  '05': 7,
#  'смс сообщения': 2048,
#  'интернете': 682,
#  'края': 800,
#  'переходе': 1418,
#  'краснодарский край': 797,
#  'хотя не': 2373,
#  'тарифов': 2223,
#  'очень черный': 1352,
#  'не давала': 1012,
#  'обновления не': 1194,
#  'вашим': 245,
#  'ноль': 1138,
#  'тарифу': 2225,
#  'тариф разговор': 2208,
#  'роутере': 1882,
#  'баланс не': 197,
#  'протяжении': 1783,
#  'действует': 436,
#  'руб сутки': 1886,
#  'оставить': 1264,
#  'хотя': 2372,
#  'трафик интернета': 2264,
#  'пишет невозможно': 1437,
#  'приобрести': 1712,
#  'списанные средства': 2120,
#  'деньги счёт': 462,
#  'которому': 783,
#  'номер xx': 1140,
#  'целый': 2382,
#  'пользования': 1589,
#  'давала': 399,
#  'полное': 1564,
#  'tuboteka': 146,
#  'осталась': 1268,
#  'свои': 1922,
#  'банковскую карту': 206,
#  'автоплатежа': 188,
#  'данного номера': 408,
#  'фамилию': 2354,
#  'сначала': 2049,
#  'использования': 691,
#  'придется': 1689,
#  'найти': 975,
#  'пришлось': 1738,
#  'заявки': 596,
#  'плохо': 1477,
#  'вообще не': 316,
#  'tuboteka ru': 148,
#  'fi': 126,
#  'звонка': 603,
#  'услуга не': 2322,
#  'не буду': 1006,
#  'который': 788,
#  'пакет услуг': 1368,
#  'заказа': 561,
#  'расходов': 1853,
#  'оплачен': 1248,
#  'мобильный': 891,
#  'платы': 1472,
#  'очень плохо': 1350,
#  'media': 134,
#  'городской': 392,
#  'скоростью': 2005,
#  'настроить': 987,
#  'проблем': 1739,
#  'никак': 1117,
#  'трафик не': 2265,
#  'x3': 157,
#  'акции': 194,
#  'либо': 808,
#  'тратится': 2262,
#  'работа': 1808,
#  'пишу': 1439,
#  'тариф очень': 2207,
#  'последние': 1644,
#  'соединения': 2082,
#  'требует': 2269,
#  'стоить': 2158,
#  'сети': 1954,
#  'ситуации': 1979,
#  'стоимость': 2155,
#  'полном': 1565,
#  'подключился': 1523,
#  'выходит': 367,
#  'новый': 1135,
#  'вконтакте': 286,
#  'никаких услуг': 1122,
#  'платных подписок': 1468,
#  '50': 102,
#  'могу перейти': 909,
#  'нескольких': 1103,
#  'дали': 402,
#  'пытаюсь': 1807,
#  'обменять': 1186,
#  'просьба': 1777,
#  'подключили': 1522,
#  'жалобу центральный': 544,
#  'возможно': 302,
#  'банк': 201,
#  'номером xx': 1158,
#  'выяснилось': 371,
#  'деньги счету': 461,
#  'нем': 1097,
#  'скорости мобильного': 1997,
#  'денежные средства': 446,
#  'прошу дать': 1795,
#  '20bd': 53,
#  'района': 1844,
#  'закинул': 571,
#  'которым': 790,
#  'именно': 659,
#  'договоре': 488,
#  'сохранением': 2096,
#  'подписки не': 1535,
#  'привязать': 1688,
#  'течение': 2254,
#  'здравствуйте сегодня': 630,
#  'tele2': 143,
#  'таких': 2194,
#  'каждого': 718,
#  'пополнить счёт': 1634,
#  'неправильно': 1102,
#  'консул x000d_': 768,
#  'перевели': 1389,
#  'работает не': 1812,
#  'текущий': 2231,
#  'мобильное приложение': 886,
#  'туда': 2275,
#  'приходит детализация': 1717,
#  'симкарты': 1975,
#  'число': 2399,
#  'дополнительные': 506,
#  'отправляются смс': 1334,
#  'стал': 2146,
#  'последний': 1645,
#  'возникает': 309,
#  'поэтому': 1661,
#  'приложения': 1702,
#  'находиться': 992,
#  'письмо': 1434,
#  'не доступна': 1016,
#  'звонки': 606,
#  'котором': 782,
#  'неудобно': 1110,
#  'помощью': 1612,
#  'подключила услугу': 1520,
#  'вводить': 251,
#  '60 рублей': 112,
#  'телефоны': 2251,
#  'затем': 589,
#  'ооо': 1231,
#  'сохранить': 2098,
#  'сверх': 1916,
#  'давно': 400,
#  'гигов': 380,
#  'включается': 284,
#  'мо': 879,
#  'поменял': 1596,
#  '1гб': 46,
#  'отключить подписку': 1308,
#  'отправить сообщение': 1326,
#  'симкарту': 1974,
#  'остатке': 1274,
#  'переадресацию': 1386,
#  'интернет телефоне': 675,
#  'вернуть мои': 264,
#  'постоянно пропадает': 1649,
#  'виджет': 278,
#  'отправить sms': 1324,
#  'операторы': 1240,
#  '300 руб': 79,
#  'живу': 547,
#  'нужна детализация': 1169,
#  'час': 2388,
#  'уходит': 2349,
#  'не переносятся': 1041,
#  'номера xx': 1148,
#  'моих': 947,
#  'отказаться': 1288,
#  'абонентской платы': 178,
#  'гигабайты минуты': 378,
#  'войти личный': 313,
#  'скорость': 1998,
#  'не имею': 1021,
#  'договор': 485,
#  'вроде': 331,
#  'меры': 851,
#  'платёж': 1473,
#  'подписывалась': 1539,
#  'вашей': 240,
#  'здравствуйте не': 622,
#  'другом регионе': 528,
#  'использую': 694,
#  'скорость падать': 2002,
#  'подключаются платные': 1499,
#  'извините': 649,
#  'купил': 804,
#  'обработку персональных': 1197,
#  'не доступен': 1015,
#  'мес': 852,
#  'не подписывался': 1050,
#  'чек': 2394,
#  'приложения не': 1703,
#  'могу отправить': 907,
#  'заранее благодарю': 585,
#  'звонки интернет': 607,
#  'еду': 534,
#  'около': 1228,
#  'могу подключить': 910,
#  'исчерпания': 701,
#  'sim карту': 140,
#  'списаны деньги': 2123,
#  '400': 95,
#  'логин': 826,
#  'не подключал': 1045,
#  'приложении теле2': 1700,
#  'интернета не': 681,
#  'плачу': 1474,
#  'не заказывала': 1018,
#  'своего': 1918,
#  'согласие обработку': 2078,
#  'предоставлен логин': 1680,
#  '10 рублей': 17,
#  'звонят': 615,
#  'воспользоваться': 321,
#  'не возможно': 1008,
#  'логин пароль': 827,
#  'подключении': 1507,
#  'пополнила баланс': 1628,
#  'причина': 1726,
#  'край': 794,
#  'подключено': 1512,
#  'старой': 2151,
#  'не поступили': 1061,
#  'поступают': 1651,
#  'возможно отправить': 303,
#  'игры': 645,
#  'предложения': 1675,
#  'частности': 2391,
#  'увидел': 2285,
#  'никаких платных': 1121,
#  'пропадают': 1765,
#  'входящие звонки': 346,
#  'банковскую': 205,
#  '80': 117,
#  'пакет не': 1366,
#  'заказ': 560,
#  '30': 72,
#  'других': 522,
#  'сих пор': 1983,
#  'сигнала': 1963,
#  'одного': 1222,
#  'сняли деньги': 2065,
#  'планируется': 1444,
#  'телефон': 2239,
#  'дополнительный': 507,
#  'просьбой': 1779,
#  'регул': 1862,
#  'оказалось': 1226,
#  'краснодарском': 798,
#  'вопроса': 317,
#  'вышка': 370,
#  'началось': 1000,
#  'другие': 520,
#  'отправки': 1327,
#  'не понимаю': 1059,
#  '30 рублей': 76,
#  'подключать': 1496,
#  'не имелось': 1020,
#  '300': 78,
#  'недели буду': 1086,
#  'обл': 1179,
#  'благодарю': 223,
#  'снять это': 2071,
#  '40': 94,
#  'переноса': 1407,
#  'пополнил': 1624,
#  'не смог': 1072,
#  'не давал': 1011,
#  'сделала': 1946,
#  'работают': 1819,
#  'низкая': 1115,
#  'услуге': 2326,
#  'утром': 2348,
#  'могу найти': 904,
#  'вызов': 354,
#  '500 мб': 107,
#  'приложение пишет': 1694,
#  'требуется': 2270,
#  'сказать': 1988,
#  'адрес': 189,
#  'имелось скорость': 658,
#  'сайты': 1901,
#  'обновления приложения': 1195,
#  'работает мобильный': 1811,
#  'абонентская': 174,
#  'самый': 1910,
#  'дней назад': 472,
#  'отключили': 1299,
#  'логотипы': 828,
#  'пакета': 1369,
#  'не перенесли': 1039,
#  'подключен тариф': 1501,
#  'минут': 863,
#  'контента': 772,
#  'разговора': 1829,
#  '19': 43,
#  'другом': 527,
#  'обновился': 1190,
#  'написать': 980,
#  'вашему': 243,
#  'смены': 2034,
#  'июне': 708,
#  'значок': 640,
#  'интернет границей': 667,
#  'эта': 2409,
#  'такого не': 2196,
#  'абонентом теле2': 173,
#  'гб': 372,
#  'оплатил': 1243,
#  'сделать': 1948,
#  'номеру 611': 1160,
#  'детализации': 466,
#  'полный': 1567,
#  'вернуть': 261,
#  'деньги списали': 457,
#  'долг': 491,
#  'времени': 326,
#  'ошибка': 1355,
#  'добавить': 477,
#  'могу пользоваться': 913,
#  'исправьте': 696,
#  'заявление': 598,
#  'пришли': 1733,
#  'черный': 2397,
#  'отключил': 1297,
#  'телефоне не': 2247,
#  'перестал работать': 1412,
#  'мобильной связи': 888,
#  'никто': 1126,
#  'могу дозвониться': 901,
#  'имеется': 656,
#  'потеряла': 1656,
#  'регион': 1858,
#  'обещанный платёж': 1178,
#  'соц': 2099,
#  'оставалось': 1263,
#  'не перешли': 1042,
#  'вынужден': 359,
#  'звонков смс': 612,
#  'лимит': 809,
#  'решить проблему': 1875,
#  'номеру': 1159,
#  'тарифного плана': 2216,
#  'ваша компания': 236,
#  'деньги сняли': 456,
#  'неверный': 1081,
#  'карта': 737,
#  'оператор': 1232,
#  'платные подписки': 1463,
#  '30 гб': 74,
#  'службы': 2017,
#  'возникла проблема': 311,
#  'ответьте': 1285,
#  'контент который': 770,
#  'списание': 2113,
#  'моем тарифе': 938,
#  'вашими': 246,
#  'приходят смс': 1723,
#  'рф': 1896,
#  'уровне': 2309,
#  'активации': 192,
#  'моего телефона': 934,
#  'версию': 270,
#  'списываются': 2133,
#  'нул': 1174,
#  '100 рублей': 20,
#  'wi fi': 153,
#  'москвы': 955,
#  'могу узнать': 919,
#  'девушка': 430,
#  'снимались': 2054,
#  'ваша': 235,
#  'доступна': 516,
#  'команду': 762,
#  'имя': 661,
#  'xx xxd_': 160,
#  'здравствуйте вчера': 618,
#  'деньги не': 454,
#  'заказе': 567,
#  'уровень сигнала': 2308,
#  'данной': 410,
#  'настройках': 988,
#  'другую': 531,
#  'снялись': 2066,
#  'не поддерживает': 1043,
#  'платный контент': 1466,
#  '15 рублей': 32,
#  'обратно': 1202,
#  'этим': 2412,
#  'продлить': 1754,
#  'приобрела': 1711,
#  'ответили': 1283,
#  'данной ситуации': 411,
#  'непонятно': 1101,
#  'будут': 229,
#  'вместо': 289,
#  'деньги контент': 451,
#  'списать': 2124,
#  'абонент': 168,
#  'перейти тариф': 1400,
#  'подключал не': 1494,
#  'второй номер': 338,
#  'билайн': 220,
#  'моб': 880,
#  '70': 115,
#  'закончился': 573,
#  'wi': 152,
#  'нагрузках сеть': 967,
#  'списываться': 2130,
#  'находясь': 993,
#  'приложение не': 1693,
#  'москва': 952,
#  'не номер': 1028,
#  'следующий месяц': 2013,
#  'подключена услуга': 1505,
#  'следствии': 2008,
#  'обновления': 1193,
#  'сайта': 1899,
#  'сим карту': 1970,
#  'несколько': 1105,
#  'сайте': 1900,
#  'исходящие': 697,
#  'образом': 1198,
#  'разблокировать': 1826,
#  'службу': 2015,
#  'невозможно отправить': 1083,
#  'сменить': 2029,
#  'подключить роуминг': 1527,
#  'управление': 2305,
#  'скорость разы': 2003,
#  'здравствуйте отключить': 625,
#  'напишите': 982,
#  'ситуацию': 1980,
#  'мобильный интернет': 892,
#  'тарифному плану': 2220,
#  'поездках': 1546,
#  'кабинету': 717,
#  'услуга': 2321,
#  'хотел узнать': 2367,
#  'расходах': 1852,
#  'здравствуйте тариф': 632,
#  'отключение': 1293,
#  'конца': 774,
#  'сообщение': 2084,
#  'средства якобы': 2141,
#  'никому': 1125,
#  'увы эта': 2288,
#  'произошло списание': 1760,
#  'году': 388,
#  '16': 39,
#  'телефоном': 2249,
#  'соответствии': 2090,
#  'центр': 2384,
#  'моём': 961,
#  'пошло': 1659,
#  '00': 0,
#  'мелодия': 843,
#  'эл': 2405,
#  'выхода': 366,
#  'конце': 776,
#  'списываются деньги': 2134,
#  'свой': 1926,
#  'доброго': 478,
#  'обещали': 1175,
#  'скорее': 1993,
#  'сочи': 2102,
#  'менял': 848,
#  'говорит': 384,
#  'отсутствует': 1340,
#  'данный момент': 418,
#  'какие услуги': 725,
#  'расходуется': 1855,
#  'узнал интернете': 2295,
#  'заблокированы': 551,
#  'подключиться': 1530,
#  'входа личный': 342,
#  'такого': 2195,
#  'необходимо': 1099,
#  '200 руб': 50,
#  'безлимит': 207,
#  'дальнейшем': 403,
#  'позвонить не': 1551,
#  'тех': 2253,
#  'зайти приложение': 559,
#  'вай': 232,
#  'хватило': 2365,
#  'подключенные': 1510,
#  'снимают': 2057,
#  'скорость не': 2000,
#  'мая': 836,
#  'надеюсь': 970,
#  'экстренные': 2403,
#  'нигде не': 1114,
#  'план': 1441,
#  'которого': 779,
#  'подключенной': 1509,
#  'недоступна': 1092,
#  'произошла': 1758,
#  'не приходят': 1065,
#  'связью': 1942,
#  'запрет': 582,
#  'отношению': 1315,
#  'картой': 740,
#  'какому': 734,
#  'ошибся': 1360,
#  'слабый': 2007,
#  'не вижу': 1007,
#  'пополните': 1630,
#  'человек': 2395,
#  'последнее': 1642,
#  'компании': 763,
#  'скорость опуститься': 2001,
#  'вк': 283,
#  'связаться': 1932,
#  'xx не': 161,
#  'не нужно': 1031,
#  '06': 8,
#  'совершить': 2076,
#  'людей': 829,
#  'баланс': 196,
#  'проблем не': 1740,
#  'платеж': 1451,
#  'услугами': 2324,
#  'договоре говорилось': 489,
#  'здраствуйте': 637,
#  'ошибочный': 1359,
#  'районе': 1845,
#  'разных': 1834,
#  'поняла': 1617,
#  'пишет': 1435,
#  'стоят': 2164,
#  '240': 58,
#  'является': 2431,
#  'вечером': 272,
#  'проблема скоростью': 1743,
#  'плюс': 1483,
#  'беспредельно черный': 218,
#  'решил': 1870,
#  'июль': 705,
#  'минус': 862,
#  'придётся': 1690,
#  'ночи': 1164,
#  'позвонила': 1549,
#  'выйти': 358,
#  'еле': 537,
#  'проблема': 1741,
#  'делать': 439,
#  'ff1f': 125,
#  'подключить услугу': 1529,
#  'увидела': 2286,
#  '450': 100,
#  'тариф заблокирован': 2202,
#  'должна': 494,
#  'паспорт': 1381,
#  'ввожу номер': 253,
#  'платить': 1454,
#  'остаток': 1279,
#  'причину': 1729,
#  'всей': 332,
#  'каким': 726,
#  'моей': 935,
#  'столько': 2160,
#  'ошибочно': 1358,
#  'рублей контент': 1888,
#  'вопросом': 318,
#  'ответ': 1281,
#  'услугой': 2331,
#  'последнее время': 1643,
#  'сигнал': 1962,
#  'двух': 429,
#  'связано': 1931,
#  'связаться оператором': 1933,
#  'пор не': 1638,
#  'одной': 1223,
#  'здравствуйте прошу': 629,
#  'оплата': 1241,
#  'сим картой': 1969,
#  'сумме': 2168,
#  'личного': 812,
#  'опция': 1259,
#  'пополнил счёт': 1626,
#  'пропадает связь': 1763,
#  'зоне': 643,
#  'перестал': 1411,
#  'нормально': 1163,
#  'московской области': 957,
#  'положительный': 1573,
#  'не заказывал': 1017,
#  'тариф не': 2205,
#  'прошлый': 1792,
#  'увы': 2287,
#  'пароль 30': 1376,
#  'подключён': 1531,
#  'надпись': 972,
#  'разъяснить': 1840,
#  'работает': 1809,
#  'видит': 280,
#  'год': 386,
#  'моем номере': 937,
#  'тарифе онлайн': 2214,
#  'падать нагрузки': 1362,
#  'такая ситуация': 2189,
#  'специально': 2105,
#  'обнаружила': 1189,
#  'санкт': 1911,
#  'роутер': 1881,
#  'сотовой': 2092,
#  'отменить': 1314,
#  'замены': 576,
#  'получила': 1580,
#  'прошу разобраться': 1803,
#  'платежа': 1452,
#  'гигабайты': 377,
#  '399': 90,
#  'оплаты': 1247,
#  'пользуюсь': 1594,
#  '350': 86,
#  'лк': 821,
#  'личном': 814,
#  'каждые': 719,
#  'пополнять': 1635,
#  'высоких': 363,
#  'перешла': 1421,
#  '50 руб': 103,
#  'случае буду': 2020,
#  'крым': 802,
#  'планшете': 1449,
#  'приложение теле2': 1696,
#  'обслуживание': 1209,
#  'услугах': 2325,
#  'вернул x000d_': 260,
#  'cloud': 122,
#  'обращалась': 1203,
#  'нужен': 1166,
#  'август': 184,
#  'уважением': 2282,
#  'очень не': 1348,
#  'августа': 185,
#  'ночью': 1165,
#  'передача': 1394,
#  'мобильная связь': 882,
#  'поменять пароль': 1602,
#  'другого человека': 526,
#  'прошу проверить': 1802,
#  'таким': 2193,
#  'счет': 2177,
#  'написать жалобу': 981,
#  'моему тарифу': 941,
#  'начиная': 1002,
#  'не работает': 1070,
#  'рублей сутки': 1893,
#  'являюсь вашим': 2434,
#  'теле': 2233,
#  'одна': 1219,
#  'вовремя': 299,
#  'пришла': 1731,
#  '22': 55,
#  'не подключать': 1047,
#  'действий': 432,
#  'внутри': 297,
#  'условиям': 2315,
#  'интернет очень': 671,
#  'баланс положительный': 198,
#  'изменения': 650,
#  'повторно': 1485,
#  'консул': 767,
#  'доброго дня': 480,
#  'хотелось': 2370,
#  'здравствуйте возникла': 617,
#  'наблюдается': 964,
#  'оформлена': 1346,
#  'регул x000d_': 1863,
#  'какое': 731,
#  'абоненты': 182,
#  'сообщить': 2088,
#  'порядке': 1639,
#  'телефону': 2250,
#  'снимать': 2056,
#  'платную': 1459,
#  'недели': 1085,
#  'место': 854,
#  'заблокировать': 552,
#  'не отправлял': 1035,
#  'не отправляются': 1037,
#  'теле2 не': 2237,
#  'заново': 578,
#  'абон плата': 167,
#  'могу получить': 912,
#  'код': 756,
#  'отключен': 1291,
#  '200 минут': 49,
#  'гб минуты': 374,
#  'роспотребнадзор': 1876,
#  'региона': 1859,
#  'услуг не': 2319,
#  'теле xx': 2234,
#  'получилось': 1581,
#  'личном кабинете': 815,
#  '300 рублей': 80,
#  'рамках': 1846,
#  'рублей это': 1894,
#  'положил': 1568,
#  'прошлом': 1790,
#  'обмена': 1185,
#  'исправить': 695,
#  'перейти': 1399,
#  '45': 99,
#  'подключает': 1490,
#  'узнать': 2296,
#  'работало': 1816,
#  'снятые': 2069,
#  'происходит': 1761,
#  'город': 389,
#  'период': 1425,
#  'входа': 341,
#  'вашего': 238,
#  'сотовой связи': 2093,
#  'те': 2229,
#  'поддерживает': 1486,
#  'эта услуга': 2411,
#  'информацию': 688,
#  'обещанный': 1176,
#  '12': 25,
#  'принять': 1709,
#  'мобильного': 883,
#  'которая': 778,
#  'мелодии': 842,
#  'выше позже': 369,
#  'предыдущий': 1682,
#  'пополнил баланс': 1625,
#  'звонил': 599,
#  'следствии скорость': 2009,
#  'true': 145,
#  'пополнен': 1620,
#  'разобраться вернуть': 1836,
#  'деньги которые': 452,
#  'iphone': 130,
#  'сети не': 1955,
#  'снимали': 2053,
#  'подписку': 1536,
#  'начала': 998,
#  'оператора связи': 1235,
#  'проблему': 1746,
#  'мои деньги': 945,
#  'номером': 1157,
#  'пользуюсь интернетом': 1595,
#  'домашнем регионе': 501,
#  'меняется': 847,
#  'причине моих': 1728,
#  'сроки': 2143,
#  'mail': 132,
#  'кабинет': 711,
#  '30р': 83,
#  'такую': 2199,
#  'сут ндс': 2173,
#  'посмотреть': 1646,
#  '150 рублей': 35,
#  'мегабайты': 838,
#  'счета': 2178,
#  'новых': 1137,
#  'пользоваться интернетом': 1591,
#  'тт': 2274,
#  'тарифный план': 2222,
#  'пор': 1637,
#  'условию договора': 2312,
#  'отправила': 1322,
#  'дело': 443,
#  '28': 68,
#  'вызова': 355,
#  'теле не': 2235,
#  'службу поддержки': 2016,
#  'перевести': 1390,
#  '15': 29,
#  'делаю': 440,
#  'уровень': 2307,
#  'доступ': 512,
#  'минута': 868,
#  'карте': 739,
#  'данных': 421,
#  'сразу': 2137,
#  'восстановится': 322,
#  'интернет трафик': 676,
#  'установке': 2338,
#  'банковской карты': 204,
#  'использовать': 692,
#  'снимаются': 2059,
#  'фамилия': 2355,
#  'расходов трафика': 1854,
#  'сотрудники': 2095,
#  'остатки': 1275,
#  'бесплатных': 216,
#  'заблокировать сим': 554,
#  'смог': 2035,
#  'второй месяц': 337,
#  'поясните': 1666,
#  'теле2': 2236,
#  'номеру телефона': 1162,
#  'июля': 706,
#  'абонентскую': 179,
#  'практически не': 1672,
#  'принимать': 1708,
#  'офиса': 1342,
#  'проверил': 1750,
#  'телефонах': 2245,
#  'тарифа онлайн': 2212,
#  'подключена платная': 1503,
#  'нужно подключить': 1171,
#  'перешла тариф': 1422,
#  'здравствуйте хотел': 633,
#  'пришло': 1735,
#  '200': 48,
#  'не отправляется': 1034,
#  'информации': 687,
#  'надоело': 971,
#  'своим номером': 1924,
#  'июня': 710,
#  'вернуть деньги': 263,
#  'не пользуюсь': 1056,
#  'купила': 805,
#  'контентный': 773,
#  'функцию': 2361,
#  'veseluxa com': 151,
#  'какую услугу': 736,
#  'баланса': 199,
#  'личному': 816,
#  'услуг': 2318,
#  'отвечает': 1286,
#  'разные': 1833,
#  'моё': 960,
#  '23': 56,
#  'перехода': 1417,
#  'сменить номер': 2030,
#  'восстановить': 324,
#  'писал': 1431,
#  'требую вернуть': 2272,
#  'телефонов': 2248,
#  'долго': 492,
#  'номере xx': 1155,
#  'кончился': 777,
#  'проседание': 1770,
#  '20': 47,
#  'симка': 1972,
#  'вынуждена': 361,
#  'операторов': 1237,
#  'поддержки': 1487,
#  'перенесли': 1401,
#  'плата': 1450,
#  'отправить': 1323,
#  ...}

# %%
X_train_tfidf.shape, X_test_tfidf.shape
# Out:
# ((90296, 2438), (10033, 2438))

# %%
ls = LogisticRegression(solver='saga', verbose=1, n_jobs=-1)
ls.fit(X_train_tfidf, y_train_labels)
# Out:
# convergence after 17 epochs took 30 seconds
# convergence after 19 epochs took 34 seconds
# convergence after 19 epochs took 34 seconds
# convergence after 20 epochs took 35 seconds
# convergence after 20 epochs took 36 seconds
# convergence after 21 epochs took 37 seconds
# convergence after 22 epochs took 38 seconds
# convergence after 23 epochs took 38 seconds
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:   38.3s remaining:   14.3s
# convergence after 18 epochs took 9 seconds
# convergence after 21 epochs took 9 seconds
# convergence after 23 epochs took 13 seconds
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:   43.4s finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='saga', tol=0.0001,
#           verbose=1, warm_start=False)

# %%
y_hat = ls.predict(X_test_tfidf)
acc_test = np.mean(y_hat==y_test_labels)

print('Accuracy on test data:', acc_test)
# Out:
# Accuracy on test data: 0.6052028306588259

# %% [markdown]
# # Visualization of predictions

# %%
def show_examples(id_example):
    
    text = data.iloc[id_example]['question']
    predicted_label = le.inverse_transform(y_hat[id_example])
    true_label = le.inverse_transform(y_test_labels[id_example])

    print('True label:', true_label)
    print('Predicted label:', predicted_label)
    print('Text:\n', text)
    display(eli5.show_prediction(ls, 
                         data.iloc[id_example]['question'], 
                         vec=tfidf,
                         #feature_names=list(tfidf.vocabulary_),
                         target_names=list(le.classes_),
                         targets=[predicted_label]))

# %%
for idd in [-1, -5, -42, -2018]:
    show_examples(idd)
# Out:
# True label: прочее
# Predicted label: поступлениеПлатежейОшибочныеПлатежи
# Text:
#  У меня списали средства за обещанный платеж  два раза хотя я его взял один раз
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=поступлениеПлатежейОшибочныеПлатежи
#
# </b>
#
#
#     (probability <b>0.339</b>, score <b>-0.452</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.802
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.254
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">у меня </span><span style="background-color: hsl(120, 100.00%, 82.65%); opacity: 0.86" title="0.418">списали</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.15%); opacity: 0.90" title="0.658">средства</span><span style="opacity: 0.80"> за </span><span style="background-color: hsl(120, 100.00%, 98.31%); opacity: 0.80" title="0.015">обещанный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.378">платеж</span><span style="opacity: 0.80">  два </span><span style="background-color: hsl(120, 100.00%, 82.11%); opacity: 0.86" title="0.436">раза</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.90%); opacity: 0.82" title="0.141">хотя</span><span style="opacity: 0.80"> я его </span><span style="background-color: hsl(0, 100.00%, 86.41%); opacity: 0.84" title="-0.295">взял</span><span style="opacity: 0.80"> один раз</span>
#     </p>
# True label: тарифыИУслуги
# Predicted label: тарифыИУслуги
# Text:
#  Здравствуйте! Какой у меня тариф?
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=тарифыИУслуги
#
# </b>
#
#
#     (probability <b>0.693</b>, score <b>0.644</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.420
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 83.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.776
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 97.96%); opacity: 0.80" title="-0.033">здравствуйте</span><span style="opacity: 0.80">! какой у меня </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="2.300">тариф</span><span style="opacity: 0.80">?</span>
#     </p>
# True label: подключенныеУслуги
# Predicted label: подключенныеУслуги
# Text:
#  Здравствуйте! Постоянно!!! Каждый месяц на этот номер подключаете платные услуги. Я команды не ввожу, всплывающие окна заблокированы. Сколько можно? Еще раз такое повториться и уйду от вас. Разберитесь пожалуйста и заблокируйте все платные услуги насовсем.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=подключенныеУслуги
#
# </b>
#
#
#     (probability <b>0.657</b>, score <b>0.401</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.118
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 81.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.717
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 93.42%); opacity: 0.82" title="0.053">здравствуйте</span><span style="opacity: 0.80">! </span><span style="background-color: hsl(120, 100.00%, 89.29%); opacity: 0.83" title="0.107">постоянно</span><span style="opacity: 0.80">!!! </span><span style="background-color: hsl(120, 100.00%, 80.07%); opacity: 0.87" title="0.259">каждый</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.99%); opacity: 0.81" title="0.047">месяц</span><span style="opacity: 0.80"> на этот </span><span style="background-color: hsl(0, 100.00%, 85.42%); opacity: 0.85" title="-0.166">номер</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.702">подключаете</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 71.15%); opacity: 0.93" title="0.440">платные</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 65.97%); opacity: 0.96" title="0.557">услуги</span><span style="opacity: 0.80">. я команды </span><span style="background-color: hsl(120, 100.00%, 95.66%); opacity: 0.81" title="0.029">не</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.69%); opacity: 0.84" title="-0.146">ввожу</span><span style="opacity: 0.80">, всплывающие окна </span><span style="background-color: hsl(0, 100.00%, 83.96%); opacity: 0.85" title="-0.190">заблокированы</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 96.71%); opacity: 0.81" title="0.020">сколько</span><span style="opacity: 0.80"> можно? еще раз </span><span style="background-color: hsl(120, 100.00%, 82.47%); opacity: 0.86" title="0.216">такое</span><span style="opacity: 0.80"> повториться и уйду от вас. </span><span style="background-color: hsl(120, 100.00%, 79.15%); opacity: 0.88" title="0.277">разберитесь</span><span style="opacity: 0.80"> пожалуйста и </span><span style="background-color: hsl(120, 100.00%, 92.76%); opacity: 0.82" title="0.061">заблокируйте</span><span style="opacity: 0.80"> все </span><span style="background-color: hsl(120, 100.00%, 71.15%); opacity: 0.93" title="0.440">платные</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 65.97%); opacity: 0.96" title="0.557">услуги</span><span style="opacity: 0.80"> насовсем.</span>
#     </p>
# True label: детализацияСчётаИлиЗвонков
# Predicted label: детализацияСчётаИлиЗвонков
# Text:
#  Хочу заказать детализацию звонков,как это сделать?
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=детализацияСчётаИлиЗвонков
#
# </b>
#
#
#     (probability <b>0.905</b>, score <b>2.809</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.102
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.293
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 97.55%); opacity: 0.80" title="0.070">хочу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.52%); opacity: 0.87" title="1.248">заказать</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="3.763">детализацию</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.57%); opacity: 0.89" title="1.753">звонков</span><span style="opacity: 0.80">,как </span><span style="background-color: hsl(0, 100.00%, 92.78%); opacity: 0.82" title="-0.326">это</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.97%); opacity: 0.82" title="-0.314">сделать</span><span style="opacity: 0.80">?</span>
#     </p>
